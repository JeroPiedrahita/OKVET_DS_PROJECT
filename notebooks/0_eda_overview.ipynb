# %% [markdown]
# **Análisis exploratorios de datos**

# %%
import os
import pandas as pd
import json
from pprint import pprint

# %% [markdown]
# ***Funcion de analisis***

# %%
def analizar_hoja(df, nombre):
    """
    Analiza un DataFrame de pandas y regresa un diccionario con los resultados.
    """
    analisis = {}
    analisis['nombre'] = nombre
    analisis['forma'] = df.shape
    analisis['columnas'] = df.columns.tolist()
    analisis['tipos_datos'] = df.dtypes.astype(str).to_dict()
    analisis['valores_nulos'] = df.isnull().sum().to_dict()
    analisis['valores_unicos'] = df.nunique().to_dict()

    # Estadísticas de tendencia central para columnas numéricas
    estadisticas = {}
    for col in df.select_dtypes(include='number').columns:
        estadisticas[col] = {
            'media': df[col].mean(),
            'mediana': df[col].median(),
            #'moda': df[col].mode().values.tolist() if not df[col].mode().empty else [],
            'nulos': int(df[col].isnull().sum())
        }
    analisis['estadisticas_tendencia_central'] = estadisticas

    # Ejemplo de los primeros 5 registros
    analisis['ejemplo'] = df.head().to_dict()

    return analisis

# %%
# 📂 Ruta a la carpeta con los archivos Excel
# carpeta = "/home/jeropf/OKVET/OKVET_DS_PROJECT/data"
carpeta = os.path.abspath(os.path.join(os.getcwd(), "../data"))

resultados_analisis = {}

for archivo in os.listdir(carpeta):
    if archivo.lower().endswith('.xlsx'):
        ruta_archivo = os.path.join(carpeta, archivo)
        try:
            excel = pd.ExcelFile(ruta_archivo)
            for hoja in excel.sheet_names:
                try:
                    df = pd.read_excel(ruta_archivo, sheet_name=hoja)
                    analisis = analizar_hoja(df, f"{archivo} - {hoja}")
                    if archivo not in resultados_analisis:
                        resultados_analisis[archivo] = {}
                    resultados_analisis[archivo][hoja] = analisis
                except Exception as e:
                    print(f"❌ Error leyendo hoja '{hoja}' en '{archivo}': {e}")
        except Exception as e:
            print(f"❌ Error abriendo archivo '{archivo}': {e}")

# %% [markdown]
# ***Extraccion de Hojas de Excel***

# %%
# ✅ Guardar resultados como JSON
try:
    with open("resumen_eda.json", "w", encoding="utf-8") as f:
        json.dump(resultados_analisis, f, indent=2, ensure_ascii=False, default=str)
    print("✅ Archivo resumen_eda.json guardado correctamente.")
except Exception as e:
    print(f"❌ Error guardando JSON: {e}")


# 👀 Revisión rápida en Jupyter Notebook (ejemplo)
# Cambia "archivo.xlsx" y "Hoja1" por los reales de tu carpeta
pprint(resultados_analisis["consultas.xlsx"]["Sheet1"]["estadisticas_tendencia_central"])
# Out:
# ✅ Archivo resumen_eda.json guardado correctamente.
# {'attitude': {'media': np.float64(0.162), 'mediana': 0.0, 'nulos': 0},
#  'cardiovascular': {'media': np.float64(0.127), 'mediana': 0.0, 'nulos': 0},
#  'differential_diagnosis': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'digestive': {'media': np.float64(0.181), 'mediana': 0.0, 'nulos': 0},
#  'dx_differential': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'dx_final': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'dx_presumptive': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'ears': {'media': np.float64(0.122), 'mediana': 0.0, 'nulos': 0},
#  'eyes': {'media': np.float64(0.135), 'mediana': 0.0, 'nulos': 0},
#  'final_diagnosis': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'hydration': {'media': np.float64(0.142), 'mediana': 0.0, 'nulos': 0},
#  'id': {'media': np.float64(1808874.5), 'mediana': 1808874.5, 'nulos': 0},
#  'import_id': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'lymph_nodes': {'media': np.float64(0.144), 'mediana': 0.0, 'nulos': 0},
#  'mucous': {'media': np.float64(0.146), 'mediana': 0.0, 'nulos': 0},
#  'muscle': {'media': np.float64(0.142), 'mediana': 0.0, 'nulos': 0},
#  'nervous': {'media': np.float64(0.124), 'mediana': 0.0, 'nulos': 0},
#  'nutritional': {'media': np.float64(0.149), 'mediana': 0.0, 'nulos': 0},
#  'pet_id': {'media': np.float64(1655070.163), 'mediana': 1974825.0, 'nulos': 0},
#  'problems': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'reproductive': {'media': np.float64(0.108), 'mediana': 0.0, 'nulos': 0},
#  'respiratory': {'media': np.float64(0.134), 'mediana': 0.0, 'nulos': 0},
#  'skin': {'media': np.float64(0.147), 'mediana': 0.0, 'nulos': 0},
#  'temperature': {'media': np.float64(39.520372670807454),
#                  'mediana': 38.5,
#                  'nulos': 678},
#  'treatment': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'urinary': {'media': np.float64(0.125), 'mediana': 0.0, 'nulos': 0},
#  'user_id': {'media': np.float64(13054.746), 'mediana': 13777.5, 'nulos': 0},
#  'vet_id': {'media': np.float64(7031.291), 'mediana': 5821.0, 'nulos': 0},
#  'waiting_room_shift_id': {'media': np.float64(23035.0),
#                            'mediana': 23029.5,
#                            'nulos': 992},
#  'weight': {'media': np.float64(16.04407310704961),
#             'mediana': 6.5,
#             'nulos': 617}}

# %% [markdown]
# ### **ANÁLISIS INDIVIDUAL DE HOJAS DE DATOS**

# %% [markdown]
# **MASCOTAS**

# %%
##Forma
print("Forma del DataFrame:")
pprint(resultados_analisis["mascotas.xlsx"]["Sheet1"]["forma"])
##Tipos de datos
print("Tipos de datos:")
pprint(resultados_analisis["mascotas.xlsx"]["Sheet1"]["tipos_datos"])
##Columnas
print("Columnas:")
pprint(resultados_analisis["mascotas.xlsx"]["Sheet1"]["columnas"])
##Valores nulos
print("Valores nulos:")
pprint(resultados_analisis["mascotas.xlsx"]["Sheet1"]["valores_nulos"])
##Estadisticas de tendencia central
print("Estadísticas de tendencia central:")
pprint(resultados_analisis["mascotas.xlsx"]["Sheet1"]["estadisticas_tendencia_central"])
##Muestra de los primeros 5 registros
print("Ejemplo de los primeros 5 registros:")
pprint(resultados_analisis["mascotas.xlsx"]["Sheet1"]["ejemplo"])
# Out:
# Forma del DataFrame:
# (1000, 22)
# Tipos de datos:
# {'birth_at': 'object',
#  'code': 'object',
#  'color': 'object',
#  'created_at': 'object',
#  'dead': 'int64',
#  'dead_at': 'object',
#  'deleted_at': 'object',
#  'food': 'object',
#  'gender_id': 'int64',
#  'id': 'int64',
#  'name': 'object',
#  'owner_id': 'int64',
#  'photo': 'object',
#  'race': 'object',
#  'race_other': 'object',
#  'reproductive_state': 'object',
#  'size_id': 'int64',
#  'specie': 'object',
#  'specie_other': 'object',
#  'updated_at': 'object',
#  'weight': 'float64',
#  'weight_unit': 'object'}
# Columnas:
# ['id',
#  'owner_id',
#  'name',
#  'specie',
#  'race',
#  'specie_other',
#  'race_other',
#  'gender_id',
#  'color',
#  'birth_at',
#  'weight',
#  'weight_unit',
#  'size_id',
#  'reproductive_state',
#  'photo',
#  'dead',
#  'dead_at',
#  'code',
#  'food',
#  'created_at',
#  'updated_at',
#  'deleted_at']
# Valores nulos:
# {'birth_at': 0,
#  'code': 914,
#  'color': 25,
#  'created_at': 0,
#  'dead': 0,
#  'dead_at': 994,
#  'deleted_at': 999,
#  'food': 653,
#  'gender_id': 0,
#  'id': 0,
#  'name': 0,
#  'owner_id': 0,
#  'photo': 954,
#  'race': 0,
#  'race_other': 951,
#  'reproductive_state': 0,
#  'size_id': 0,
#  'specie': 0,
#  'specie_other': 991,
#  'updated_at': 0,
#  'weight': 0,
#  'weight_unit': 0}
# Estadísticas de tendencia central:
# {'dead': {'media': np.float64(0.006), 'mediana': 0.0, 'nulos': 0},
#  'gender_id': {'media': np.float64(1.525), 'mediana': 2.0, 'nulos': 0},
#  'id': {'media': np.float64(1977310.5), 'mediana': 1977310.5, 'nulos': 0},
#  'owner_id': {'media': np.float64(1367892.185),
#               'mediana': 1488026.5,
#               'nulos': 0},
#  'size_id': {'media': np.float64(2.625), 'mediana': 3.0, 'nulos': 0},
#  'weight': {'media': np.float64(35.145019999999995),
#             'mediana': 5.0,
#             'nulos': 0}}
# Ejemplo de los primeros 5 registros:
# {'birth_at': {0: '2021-01-17',
#               1: '2024-12-07',
#               2: '2023-06-20',
#               3: '2025-01-17',
#               4: '0204-02-12'},
#  'code': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'color': {0: 'DORTADO BLANCO',
#            1: 'Atigrado',
#            2: 'Blanco',
#            3: 'Negro',
#            4: 'Marrón'},
#  'created_at': {0: '2025-05-28 12:15:23',
#                 1: '2025-05-28 11:15:17',
#                 2: '2025-05-28 11:15:06',
#                 3: '2025-05-28 10:15:02',
#                 4: '2025-05-28 11:14:31'},
#  'dead': {0: 0, 1: 0, 2: 0, 3: 0, 4: 0},
#  'dead_at': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'deleted_at': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'food': {0: nan, 1: 'Br for Cats', 2: nan, 3: nan, 4: nan},
#  'gender_id': {0: 1, 1: 1, 2: 2, 3: 2, 4: 1},
#  'id': {0: 1977810, 1: 1977809, 2: 1977808, 3: 1977807, 4: 1977806},
#  'name': {0: 'SAM', 1: 'Milo', 2: 'LUNA GIRO', 3: 'Cloe', 4: 'STARKY'},
#  'owner_id': {0: 1488512, 1: 1299508, 2: 1488511, 3: 1442518, 4: 1488507},
#  'photo': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'race': {0: 'mestizo',
#           1: 'mestizo',
#           2: 'criolloa',
#           3: 'persa',
#           4: 'french_poodle'},
#  'race_other': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'reproductive_state': {0: 'sterilized',
#                         1: 'unsterilized',
#                         2: 'sterilized',
#                         3: 'unsterilized',
#                         4: 'unknow'},
#  'size_id': {0: 3, 1: 2, 2: 2, 3: 2, 4: 3},
#  'specie': {0: 'canine', 1: 'feline', 2: 'feline', 3: 'feline', 4: 'canine'},
#  'specie_other': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'updated_at': {0: '2025-05-28 12:15:23',
#                 1: '2025-05-28 11:15:17',
#                 2: '2025-05-28 11:15:06',
#                 3: '2025-05-28 10:15:02',
#                 4: '2025-05-28 11:14:31'},
#  'weight': {0: 0.0, 1: 3.0, 2: 0.0, 3: 2.3, 4: 1.0},
#  'weight_unit': {0: 'kg', 1: 'kg', 2: 'kg', 3: 'kg', 4: 'kg'}}

# %% [markdown]
# Las columnas que se puede quitar son: weight_unit, race_other, photo, dead_at, delete_at.
# Crear una columna llamada Edad a partir del nacimiento

# %% [markdown]
# **CITAS**

# %%
##Forma
print("Forma del DataFrame:")
pprint(resultados_analisis["citas.xlsx"]["Sheet1"]["forma"])
##Tipos de datos
print("Tipos de datos:")
pprint(resultados_analisis["citas.xlsx"]["Sheet1"]["tipos_datos"])
##Columnas
print("Columnas:")
pprint(resultados_analisis["citas.xlsx"]["Sheet1"]["columnas"])
##Valores nulos
print("Valores nulos:")
pprint(resultados_analisis["citas.xlsx"]["Sheet1"]["valores_nulos"])
##Estadisticas de tendencia central
print("Estadísticas de tendencia central:")
pprint(resultados_analisis["citas.xlsx"]["Sheet1"]["estadisticas_tendencia_central"])
##Muestra de los primeros 5 registros
print("Ejemplo de los primeros 5 registros:")
pprint(resultados_analisis["citas.xlsx"]["Sheet1"]["ejemplo"])
# Out:
# Forma del DataFrame:
# (1000, 23)
# Tipos de datos:
# {'assistance': 'object',
#  'calendar_id': 'int64',
#  'comments': 'object',
#  'created_at': 'object',
#  'deleted_at': 'object',
#  'description': 'object',
#  'end': 'object',
#  'event_id': 'float64',
#  'form_id': 'float64',
#  'form_type': 'object',
#  'id': 'int64',
#  'owner_id': 'float64',
#  'pet_id': 'float64',
#  'responsible_id': 'float64',
#  'start': 'object',
#  'subtype': 'object',
#  'summary': 'object',
#  'type': 'object',
#  'updated_at': 'object',
#  'user_id': 'int64',
#  'variables': 'object',
#  'vet_id': 'int64',
#  'waiting_room_shift_id': 'float64'}
# Columnas:
# ['id',
#  'calendar_id',
#  'vet_id',
#  'owner_id',
#  'pet_id',
#  'user_id',
#  'responsible_id',
#  'event_id',
#  'type',
#  'subtype',
#  'summary',
#  'description',
#  'start',
#  'end',
#  'assistance',
#  'comments',
#  'form_id',
#  'form_type',
#  'variables',
#  'waiting_room_shift_id',
#  'created_at',
#  'updated_at',
#  'deleted_at']
# Valores nulos:
# {'assistance': 0,
#  'calendar_id': 0,
#  'comments': 996,
#  'created_at': 0,
#  'deleted_at': 992,
#  'description': 793,
#  'end': 0,
#  'event_id': 1000,
#  'form_id': 504,
#  'form_type': 504,
#  'id': 0,
#  'owner_id': 76,
#  'pet_id': 90,
#  'responsible_id': 612,
#  'start': 0,
#  'subtype': 943,
#  'summary': 0,
#  'type': 0,
#  'updated_at': 0,
#  'user_id': 0,
#  'variables': 484,
#  'vet_id': 0,
#  'waiting_room_shift_id': 1000}
# Estadísticas de tendencia central:
# {'calendar_id': {'media': 2847.109, 'mediana': 2464.0, 'nulos': 0},
#  'event_id': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'form_id': {'media': 912339.3004032258, 'mediana': 934989.5, 'nulos': 504},
#  'id': {'media': 1315543.121, 'mediana': 1315542.5, 'nulos': 0},
#  'owner_id': {'media': 1035685.7316017316, 'mediana': 1254412.0, 'nulos': 76},
#  'pet_id': {'media': 1505043.9648351648, 'mediana': 1847571.0, 'nulos': 90},
#  'responsible_id': {'media': 11487.064432989691,
#                     'mediana': 11007.0,
#                     'nulos': 612},
#  'user_id': {'media': 12515.29, 'mediana': 12430.0, 'nulos': 0},
#  'vet_id': {'media': 6319.675, 'mediana': 4365.0, 'nulos': 0},
#  'waiting_room_shift_id': {'media': nan, 'mediana': nan, 'nulos': 1000}}
# Ejemplo de los primeros 5 registros:
# {'assistance': {0: 'pending',
#                 1: 'pending',
#                 2: 'pending',
#                 3: 'preregistration',
#                 4: 'pending'},
#  'calendar_id': {0: 3644, 1: 5, 2: 3049, 3: 6650, 4: 349},
#  'comments': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'created_at': {0: '2025-05-28 12:07:30',
#                 1: '2025-05-28 13:07:24',
#                 2: '2025-05-28 13:06:43',
#                 3: '2025-05-28 12:05:44',
#                 4: '2025-05-28 13:05:34'},
#  'deleted_at': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'description': {0: 'VACUNA ANUAL TRIPLE, LEUCEMIA, RABIA',
#                  1: nan,
#                  2: 'ICY',
#                  3: nan,
#                  4: 'CON RT'},
#  'end': {0: '2026-05-28 01:30:00',
#          1: '2025-05-28 13:37:00',
#          2: '2025-05-28 19:30:00',
#          3: '2025-05-30 00:00:00',
#          4: '2025-05-29 08:30:00'},
#  'event_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'form_id': {0: nan, 1: nan, 2: nan, 3: 1809591.0, 4: nan},
#  'form_type': {0: nan, 1: nan, 2: nan, 3: 'App\\Models\\Consult', 4: nan},
#  'id': {0: 1316060, 1: 1316059, 2: 1316058, 3: 1316057, 4: 1316056},
#  'owner_id': {0: 916282.0, 1: 475750.0, 2: nan, 3: 1488761.0, 4: 72113.0},
#  'pet_id': {0: 1179494.0, 1: 597468.0, 2: nan, 3: 1978147.0, 4: 603164.0},
#  'responsible_id': {0: 15478.0, 1: nan, 2: nan, 3: nan, 4: 61.0},
#  'start': {0: '2026-05-28 01:00:00',
#            1: '2025-05-28 13:07:00',
#            2: '2025-05-28 18:30:00',
#            3: '2025-05-30 00:00:00',
#            4: '2025-05-29 08:00:00'},
#  'subtype': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'summary': {0: 'Vacunación - RINA VETERINARIA',
#              1: 'Examen de laboratorio - MAKROPET',
#              2: 'RETIRO DE PUNTOS - ANIMALIFE GROUP S.A.S',
#              3: 'Consulta - Soluciones Quirurgicas Veterinarias',
#              4: 'Seguimiento - AQUAVET CLÍNICA VETERINARIA SAS'},
#  'type': {0: 'vaccine', 1: 'laboratory', 2: 'other', 3: 'consult', 4: 'check'},
#  'updated_at': {0: '2025-05-28 12:07:30',
#                 1: '2025-05-28 13:07:24',
#                 2: '2025-05-28 13:06:43',
#                 3: '2025-05-28 12:05:44',
#                 4: '2025-05-28 13:05:34'},
#  'user_id': {0: 8236, 1: 10613, 2: 1306, 3: 23988, 4: 331},
#  'variables': {0: '{"vet_location": true}',
#                1: '{"vet_location": true}',
#                2: '{"custom_type": "RETIRO DE PUNTOS", "vet_location": true}',
#                3: nan,
#                4: '{"ical": "6837506ee9c4d@calendar.okvet.co", "vet_location": '
#                   'true}'},
#  'vet_id': {0: 8070, 1: 422, 2: 6240, 3: 16324, 4: 23},
#  'waiting_room_shift_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan}}

# %% [markdown]
# NOTAS:

# %% [markdown]
# **Consultas**

# %%
##Forma
print("Forma del DataFrame:")
pprint(resultados_analisis["consultas.xlsx"]["Sheet1"]["forma"])
##Tipos de datos
print("Tipos de datos:")
pprint(resultados_analisis["consultas.xlsx"]["Sheet1"]["tipos_datos"])
##Columnas
print("Columnas:")
pprint(resultados_analisis["consultas.xlsx"]["Sheet1"]["columnas"])
##Valores nulos
print("Valores nulos:")
pprint(resultados_analisis["consultas.xlsx"]["Sheet1"]["valores_nulos"])
##Estadisticas de tendencia central
print("Estadísticas de tendencia central:")
pprint(resultados_analisis["consultas.xlsx"]["Sheet1"]["estadisticas_tendencia_central"])
##Muestra de los primeros 5 registros
print("Ejemplo de los primeros 5 registros:")
pprint(resultados_analisis["consultas.xlsx"]["Sheet1"]["ejemplo"])
# Out:
# Forma del DataFrame:
# (1000, 71)
# Tipos de datos:
# {'anamnesis': 'object',
#  'attitude': 'int64',
#  'attitude_obs': 'object',
#  'bcs': 'object',
#  'blood_pressure': 'object',
#  'breathing_rate': 'object',
#  'cardiovascular': 'int64',
#  'cardiovascular_obs': 'object',
#  'consult_at': 'object',
#  'created_at': 'object',
#  'crt': 'object',
#  'deleted_at': 'object',
#  'diagnostic_plan': 'object',
#  'differential_diagnosis': 'float64',
#  'digestive': 'int64',
#  'digestive_obs': 'object',
#  'dx_differential': 'float64',
#  'dx_final': 'float64',
#  'dx_presumptive': 'float64',
#  'ears': 'int64',
#  'ears_obs': 'object',
#  'eyes': 'int64',
#  'eyes_obs': 'object',
#  'file': 'object',
#  'final_diagnosis': 'float64',
#  'glycemia': 'object',
#  'heart_rate': 'object',
#  'heartbeat': 'object',
#  'hydration': 'int64',
#  'hydration_obs': 'object',
#  'id': 'int64',
#  'import_id': 'float64',
#  'interpretation': 'object',
#  'lymph_nodes': 'int64',
#  'lymph_nodes_obs': 'object',
#  'mucous': 'int64',
#  'mucous_membrane': 'object',
#  'mucous_obs': 'object',
#  'muscle': 'int64',
#  'muscle_obs': 'object',
#  'nervous': 'int64',
#  'nervous_obs': 'object',
#  'next_control_at': 'object',
#  'nutritional': 'int64',
#  'nutritional_obs': 'object',
#  'objetive': 'object',
#  'observations': 'object',
#  'palpation': 'object',
#  'pet_id': 'int64',
#  'problems': 'float64',
#  'reflexes': 'object',
#  'reproductive': 'int64',
#  'reproductive_obs': 'object',
#  'respiratory': 'int64',
#  'respiratory_obs': 'object',
#  'saturation': 'object',
#  'skin': 'int64',
#  'skin_obs': 'object',
#  'temperature': 'float64',
#  'temperature_unit': 'object',
#  'therapeutic_plan': 'object',
#  'treatment': 'float64',
#  'type': 'object',
#  'updated_at': 'object',
#  'urinary': 'int64',
#  'urinary_obs': 'object',
#  'user_id': 'int64',
#  'vet_id': 'int64',
#  'waiting_room_shift_id': 'float64',
#  'weight': 'float64',
#  'weight_unit': 'object'}
# Columnas:
# ['id',
#  'pet_id',
#  'vet_id',
#  'user_id',
#  'consult_at',
#  'type',
#  'anamnesis',
#  'objetive',
#  'problems',
#  'differential_diagnosis',
#  'interpretation',
#  'diagnostic_plan',
#  'therapeutic_plan',
#  'final_diagnosis',
#  'treatment',
#  'next_control_at',
#  'temperature',
#  'temperature_unit',
#  'weight',
#  'weight_unit',
#  'bcs',
#  'crt',
#  'heart_rate',
#  'breathing_rate',
#  'reflexes',
#  'heartbeat',
#  'saturation',
#  'blood_pressure',
#  'mucous_membrane',
#  'glycemia',
#  'palpation',
#  'observations',
#  'attitude',
#  'attitude_obs',
#  'hydration',
#  'hydration_obs',
#  'nutritional',
#  'nutritional_obs',
#  'lymph_nodes',
#  'lymph_nodes_obs',
#  'mucous',
#  'mucous_obs',
#  'cardiovascular',
#  'cardiovascular_obs',
#  'respiratory',
#  'respiratory_obs',
#  'digestive',
#  'digestive_obs',
#  'urinary',
#  'urinary_obs',
#  'reproductive',
#  'reproductive_obs',
#  'muscle',
#  'muscle_obs',
#  'nervous',
#  'nervous_obs',
#  'skin',
#  'skin_obs',
#  'eyes',
#  'eyes_obs',
#  'ears',
#  'ears_obs',
#  'import_id',
#  'waiting_room_shift_id',
#  'file',
#  'dx_presumptive',
#  'dx_differential',
#  'dx_final',
#  'created_at',
#  'updated_at',
#  'deleted_at']
# Valores nulos:
# {'anamnesis': 0,
#  'attitude': 0,
#  'attitude_obs': 958,
#  'bcs': 726,
#  'blood_pressure': 913,
#  'breathing_rate': 753,
#  'cardiovascular': 0,
#  'cardiovascular_obs': 988,
#  'consult_at': 0,
#  'created_at': 0,
#  'crt': 712,
#  'deleted_at': 994,
#  'diagnostic_plan': 419,
#  'differential_diagnosis': 1000,
#  'digestive': 0,
#  'digestive_obs': 936,
#  'dx_differential': 1000,
#  'dx_final': 1000,
#  'dx_presumptive': 1000,
#  'ears': 0,
#  'ears_obs': 988,
#  'eyes': 0,
#  'eyes_obs': 978,
#  'file': 963,
#  'final_diagnosis': 1000,
#  'glycemia': 930,
#  'heart_rate': 733,
#  'heartbeat': 793,
#  'hydration': 0,
#  'hydration_obs': 978,
#  'id': 0,
#  'import_id': 1000,
#  'interpretation': 305,
#  'lymph_nodes': 0,
#  'lymph_nodes_obs': 977,
#  'mucous': 0,
#  'mucous_membrane': 699,
#  'mucous_obs': 974,
#  'muscle': 0,
#  'muscle_obs': 971,
#  'nervous': 0,
#  'nervous_obs': 984,
#  'next_control_at': 854,
#  'nutritional': 0,
#  'nutritional_obs': 970,
#  'objetive': 0,
#  'observations': 910,
#  'palpation': 835,
#  'pet_id': 0,
#  'problems': 1000,
#  'reflexes': 813,
#  'reproductive': 0,
#  'reproductive_obs': 991,
#  'respiratory': 0,
#  'respiratory_obs': 982,
#  'saturation': 910,
#  'skin': 0,
#  'skin_obs': 963,
#  'temperature': 678,
#  'temperature_unit': 677,
#  'therapeutic_plan': 272,
#  'treatment': 1000,
#  'type': 0,
#  'updated_at': 0,
#  'urinary': 0,
#  'urinary_obs': 982,
#  'user_id': 0,
#  'vet_id': 0,
#  'waiting_room_shift_id': 992,
#  'weight': 617,
#  'weight_unit': 614}
# Estadísticas de tendencia central:
# {'attitude': {'media': 0.162, 'mediana': 0.0, 'nulos': 0},
#  'cardiovascular': {'media': 0.127, 'mediana': 0.0, 'nulos': 0},
#  'differential_diagnosis': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'digestive': {'media': 0.181, 'mediana': 0.0, 'nulos': 0},
#  'dx_differential': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'dx_final': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'dx_presumptive': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'ears': {'media': 0.122, 'mediana': 0.0, 'nulos': 0},
#  'eyes': {'media': 0.135, 'mediana': 0.0, 'nulos': 0},
#  'final_diagnosis': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'hydration': {'media': 0.142, 'mediana': 0.0, 'nulos': 0},
#  'id': {'media': 1808874.5, 'mediana': 1808874.5, 'nulos': 0},
#  'import_id': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'lymph_nodes': {'media': 0.144, 'mediana': 0.0, 'nulos': 0},
#  'mucous': {'media': 0.146, 'mediana': 0.0, 'nulos': 0},
#  'muscle': {'media': 0.142, 'mediana': 0.0, 'nulos': 0},
#  'nervous': {'media': 0.124, 'mediana': 0.0, 'nulos': 0},
#  'nutritional': {'media': 0.149, 'mediana': 0.0, 'nulos': 0},
#  'pet_id': {'media': 1655070.163, 'mediana': 1974825.0, 'nulos': 0},
#  'problems': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'reproductive': {'media': 0.108, 'mediana': 0.0, 'nulos': 0},
#  'respiratory': {'media': 0.134, 'mediana': 0.0, 'nulos': 0},
#  'skin': {'media': 0.147, 'mediana': 0.0, 'nulos': 0},
#  'temperature': {'media': 39.520372670807454, 'mediana': 38.5, 'nulos': 678},
#  'treatment': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'urinary': {'media': 0.125, 'mediana': 0.0, 'nulos': 0},
#  'user_id': {'media': 13054.746, 'mediana': 13777.5, 'nulos': 0},
#  'vet_id': {'media': 7031.291, 'mediana': 5821.0, 'nulos': 0},
#  'waiting_room_shift_id': {'media': 23035.0, 'mediana': 23029.5, 'nulos': 992},
#  'weight': {'media': 16.04407310704961, 'mediana': 6.5, 'nulos': 617}}
# Ejemplo de los primeros 5 registros:
# {'anamnesis': {0: 'han notado desde hace 3 dias que esta decaida, y no ha '
#                   'comido bien, esta en celo',
#                1: 'Tutora se acerca a consulta geeral para esterilizacion\n'
#                   '\n'
#                   'defeca: duro \n'
#                   'vomito: no\n'
#                   'alimento: agility gold\n'
#                   'estornudos: no / tos: no',
#                2: 'Paciente con masa en la zona cigomática izquierda de '
#                   'crecimiento acelerado y ulcerado, viene a consulta con el '
#                   'oncólogo, para evaluar tratamiento quirúrgico.',
#                3: 'Propietario reporta que: El sabado empezó a oler como a '
#                   'mortango y tenia un sapo en la boca y ya el lunes empezó '
#                   'con ataques.\n'
#                   'Desparasitación: Hace mes y medio. \n'
#                   'Vacunación: TODAS (SIN REPORTE DE CARNÉ).\n'
#                   'Antecedente medico: NO REPORTA',
#                4: 'C: él ve que apoya mejor, el ejercicio de escalón delantero '
#                   'se lo hace mientras come y todo bien'},
#  'attitude': {0: 0, 1: 0, 2: 0, 3: 0, 4: 0},
#  'attitude_obs': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'bcs': {0: nan, 1: nan, 2: nan, 3: '2/5', 4: nan},
#  'blood_pressure': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'breathing_rate': {0: nan, 1: nan, 2: nan, 3: '-', 4: nan},
#  'cardiovascular': {0: 0, 1: 0, 2: 0, 3: 0, 4: 0},
#  'cardiovascular_obs': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'consult_at': {0: '2025-05-25 10:38:00',
#                 1: '2025-05-28 11:41:00',
#                 2: '2025-05-28 12:40:00',
#                 3: '2025-05-28 11:37:00',
#                 4: '2025-05-27 18:00:00'},
#  'created_at': {0: '2025-05-28 10:42:06',
#                 1: '2025-05-28 11:41:56',
#                 2: '2025-05-28 12:41:53',
#                 3: '2025-05-28 11:40:56',
#                 4: '2025-05-28 10:40:44'},
#  'crt': {0: nan, 1: nan, 2: nan, 3: '2 segundo', 4: nan},
#  'deleted_at': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'diagnostic_plan': {0: 'ultrasonido \nestudios de laboratorio',
#                      1: nan,
#                      2: nan,
#                      3: 'Test de distemper canino (POSITIVO).',
#                      4: 'Se continúa con los mismos ejercicios a casa de su '
#                         'cita anterior'},
#  'differential_diagnosis': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'digestive': {0: 0, 1: 0, 2: 0, 3: 0, 4: 0},
#  'digestive_obs': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'dx_differential': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'dx_final': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'dx_presumptive': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'ears': {0: 0, 1: 0, 2: 0, 3: 0, 4: 0},
#  'ears_obs': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'eyes': {0: 0, 1: 0, 2: 0, 3: 0, 4: 0},
#  'eyes_obs': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'file': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'final_diagnosis': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'glycemia': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'heart_rate': {0: nan, 1: nan, 2: nan, 3: '-', 4: nan},
#  'heartbeat': {0: nan, 1: nan, 2: nan, 3: '-', 4: nan},
#  'hydration': {0: 0, 1: 0, 2: 0, 3: 0, 4: 0},
#  'hydration_obs': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'id': {0: 1809374, 1: 1809373, 2: 1809372, 3: 1809371, 4: 1809370},
#  'import_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'interpretation': {0: 'piometra\ntumor abdominal',
#                     1: nan,
#                     2: nan,
#                     3: 'Distemper canino',
#                     4: nan},
#  'lymph_nodes': {0: 0, 1: 0, 2: 0, 3: 0, 4: 0},
#  'lymph_nodes_obs': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'mucous': {0: 0, 1: 0, 2: 0, 3: 0, 4: 0},
#  'mucous_membrane': {0: nan, 1: nan, 2: nan, 3: 'pale_pink', 4: nan},
#  'mucous_obs': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'muscle': {0: 0, 1: 0, 2: 0, 3: 0, 4: 0},
#  'muscle_obs': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'nervous': {0: 0, 1: 0, 2: 0, 3: 0, 4: 0},
#  'nervous_obs': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'next_control_at': {0: '2025-06-02', 1: nan, 2: nan, 3: nan, 4: nan},
#  'nutritional': {0: 0, 1: 0, 2: 0, 3: 0, 4: 0},
#  'nutritional_obs': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'objetive': {0: 'dolor abdominal, secreción en la vulva, temp. 37\n'
#                  'abdomen abultado',
#               1: '-',
#               2: 'Tumor de 7 centímetros de diámetro',
#               3: 'Paciente se encuentra con alteración neurologica, presenta '
#                  'bruxismo, a la auscultación cardiopulmonar no se escuchan '
#                  'alteraciones, no hay dolor a la palpación abdominal, '
#                  'presenta mucina ocular seca con conjuntivitis, presenta '
#                  'secrecion nasal, paciente ataxica, condicion corporal baja, '
#                  'presenta sialorrea durante episodio convulsivo, mal olor '
#                  'corporal.',
#               4: 'M: Dolor a la palpación de sartorio mpizq y cuádriceps '
#                  'mpder'},
#  'observations': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'palpation': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'pet_id': {0: 1977896, 1: 1624048, 2: 1977886, 3: 1977892, 4: 1921283},
#  'problems': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'reflexes': {0: nan, 1: nan, 2: nan, 3: '-', 4: nan},
#  'reproductive': {0: 0, 1: 0, 2: 0, 3: 0, 4: 0},
#  'reproductive_obs': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'respiratory': {0: 0, 1: 0, 2: 0, 3: 0, 4: 0},
#  'respiratory_obs': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'saturation': {0: nan, 1: nan, 2: nan, 3: '-', 4: nan},
#  'skin': {0: 0, 1: 0, 2: 0, 3: 0, 4: 0},
#  'skin_obs': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'temperature': {0: nan, 1: nan, 2: nan, 3: 38.5, 4: nan},
#  'temperature_unit': {0: nan, 1: nan, 2: nan, 3: 'c', 4: nan},
#  'therapeutic_plan': {0: 'hospitalizacion',
#                       1: nan,
#                       2: nan,
#                       3: 'Retrovirales\nInmuno estimulantes',
#                       4: '⚠️ El dueño coloca bozal #5 y pechera negra. '
#                          'Colgamos en riel de pechera y ponemos faja #4. '
#                          'Pedirle al dueño que sujete cabeza en todo '
#                          'momento. \n'
#                          '\n'
#                          'Láser 5 a 250 cadera, rodilla, sartorio, '
#                          'isquiotibiales, cuádriceps bilateral y gastrocnemio '
#                          'mpder. \n'
#                          'Electro 2p cadera a rodilla bilateral \n'
#                          '\n'
#                          '*Ya sin bozal y que lo maneje el dueño: \n'
#                          'Ejercicio: Cavalleti nivel 1 cruzado con palitos '
#                          'verdes x3 \n'
#                          'Zigzag x3 (con 3 obstáculos)\n'
#                          'Subir y bajar escalón doble x3  \n'
#                          'Escalón delantero doble 10seg x3 (hacerlo con '
#                          'galletas, cuidado que las arranca)'},
#  'treatment': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'type': {0: 'general', 1: 'general', 2: 'general', 3: 'general', 4: 'general'},
#  'updated_at': {0: '2025-05-28 10:42:06',
#                 1: '2025-05-28 11:41:56',
#                 2: '2025-05-28 12:41:53',
#                 3: '2025-05-28 11:40:56',
#                 4: '2025-05-28 10:40:44'},
#  'urinary': {0: 0, 1: 0, 2: 0, 3: 0, 4: 0},
#  'urinary_obs': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'user_id': {0: 12744, 1: 22659, 2: 21816, 3: 13556, 4: 17258},
#  'vet_id': {0: 16310, 1: 8374, 2: 14705, 3: 8882, 4: 3742},
#  'waiting_room_shift_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'weight': {0: nan, 1: nan, 2: nan, 3: 6.0, 4: nan},
#  'weight_unit': {0: nan, 1: nan, 2: nan, 3: 'kg', 4: nan}}

# %% [markdown]
# Notas: Muchas columnas de descripciones-Muchas columnas con valores nulos

# %% [markdown]
# **Desparasitaciones**

# %%
##Forma
print("Forma del DataFrame:")
pprint(resultados_analisis["desparasitaciones.xlsx"]["Sheet1"]["forma"])
##Tipos de datos
print("Tipos de datos:")
pprint(resultados_analisis["desparasitaciones.xlsx"]["Sheet1"]["tipos_datos"])
##Columnas
print("Columnas:")
pprint(resultados_analisis["desparasitaciones.xlsx"]["Sheet1"]["columnas"])
##Valores nulos
print("Valores nulos:")
pprint(resultados_analisis["desparasitaciones.xlsx"]["Sheet1"]["valores_nulos"])
##Estadisticas de tendencia central
print("Estadísticas de tendencia central:")
pprint(resultados_analisis["desparasitaciones.xlsx"]["Sheet1"]["estadisticas_tendencia_central"])
##Muestra de los primeros 5 registros
print("Ejemplo de los primeros 5 registros:")
pprint(resultados_analisis["desparasitaciones.xlsx"]["Sheet1"]["ejemplo"])
# Out:
# Forma del DataFrame:
# (1000, 15)
# Tipos de datos:
# {'created_at': 'object',
#  'deleted_at': 'object',
#  'details': 'object',
#  'deworming_at': 'object',
#  'dose': 'object',
#  'file': 'object',
#  'id': 'int64',
#  'last_deworming': 'object',
#  'next_control_at': 'object',
#  'pet_id': 'int64',
#  'product': 'object',
#  'updated_at': 'object',
#  'user_id': 'int64',
#  'vet_id': 'int64',
#  'waiting_room_shift_id': 'float64'}
# Columnas:
# ['id',
#  'pet_id',
#  'vet_id',
#  'user_id',
#  'deworming_at',
#  'product',
#  'dose',
#  'last_deworming',
#  'next_control_at',
#  'file',
#  'details',
#  'waiting_room_shift_id',
#  'created_at',
#  'updated_at',
#  'deleted_at']
# Valores nulos:
# {'created_at': 0,
#  'deleted_at': 997,
#  'details': 659,
#  'deworming_at': 0,
#  'dose': 0,
#  'file': 0,
#  'id': 0,
#  'last_deworming': 609,
#  'next_control_at': 226,
#  'pet_id': 0,
#  'product': 0,
#  'updated_at': 0,
#  'user_id': 0,
#  'vet_id': 0,
#  'waiting_room_shift_id': 1000}
# Estadísticas de tendencia central:
# {'id': {'media': 396647.5, 'mediana': 396647.5, 'nulos': 0},
#  'pet_id': {'media': 1628790.099, 'mediana': 1931593.0, 'nulos': 0},
#  'user_id': {'media': 12641.416, 'mediana': 11697.0, 'nulos': 0},
#  'vet_id': {'media': 7031.654, 'mediana': 5326.0, 'nulos': 0},
#  'waiting_room_shift_id': {'media': nan, 'mediana': nan, 'nulos': 1000}}
# Ejemplo de los primeros 5 registros:
# {'created_at': {0: '2025-05-28 14:52:34',
#                 1: '2025-05-28 10:49:35',
#                 2: '2025-05-28 11:48:56',
#                 3: '2025-05-28 12:47:25',
#                 4: '2025-05-28 11:47:10'},
#  'deleted_at': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'details': {0: nan,
#              1: nan,
#              2: nan,
#              3: nan,
#              4: 'Lo DESP con FARMENZOL el 23-24 y 25/5'},
#  'deworming_at': {0: '2025-02-04',
#                   1: '2025-05-28',
#                   2: '2025-05-13',
#                   3: '2025-05-28',
#                   4: '2025-05-23'},
#  'dose': {0: '-', 1: '1 tableta', 2: '1/2', 3: '1/4', 4: 'x 3d'},
#  'file': {0: '[]', 1: '[]', 2: '[]', 3: '[]', 4: '[]'},
#  'id': {0: 397147, 1: 397146, 2: 397145, 3: 397144, 4: 397143},
#  'last_deworming': {0: nan, 1: nan, 2: '2025-05-13', 3: nan, 4: nan},
#  'next_control_at': {0: nan,
#                      1: nan,
#                      2: '2025-05-29',
#                      3: '2025-06-18',
#                      4: '2025-06-18'},
#  'pet_id': {0: 1236276, 1: 1876773, 2: 1978095, 3: 1978114, 4: 1978056},
#  'product': {0: 'AFOXOPET DE 10 A 25 KG',
#              1: 'Drontal plus',
#              2: 'endogard',
#              3: 'VERMIC TOTAL',
#              4: 'FARMENZOL'},
#  'updated_at': {0: '2025-05-28 14:52:34',
#                 1: '2025-05-28 10:49:35',
#                 2: '2025-05-28 11:48:56',
#                 3: '2025-05-28 12:47:25',
#                 4: '2025-05-28 11:47:10'},
#  'user_id': {0: 4839, 1: 9843, 2: 23988, 3: 8411, 4: 18022},
#  'vet_id': {0: 3047, 1: 10808, 2: 16324, 3: 5263, 4: 10299},
#  'waiting_room_shift_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan}}

# %% [markdown]
# Notas: Se pueden eliminar las fechas, me parece que lo importante es lo que usan para desparasitar

# %% [markdown]
# **Documentos**

# %%
##Forma
print("Forma del DataFrame:")
pprint(resultados_analisis["documentos.xlsx"]["Sheet1"]["forma"])
##Tipos de datos
print("Tipos de datos:")
pprint(resultados_analisis["documentos.xlsx"]["Sheet1"]["tipos_datos"])
##Columnas
print("Columnas:")
pprint(resultados_analisis["documentos.xlsx"]["Sheet1"]["columnas"])
##Valores nulos
print("Valores nulos:")
pprint(resultados_analisis["documentos.xlsx"]["Sheet1"]["valores_nulos"])
##Estadisticas de tendencia central
print("Estadísticas de tendencia central:")
pprint(resultados_analisis["documentos.xlsx"]["Sheet1"]["estadisticas_tendencia_central"])
##Muestra de los primeros 5 registros
print("Ejemplo de los primeros 5 registros:")
pprint(resultados_analisis["documentos.xlsx"]["Sheet1"]["ejemplo"])
# Out:
# Forma del DataFrame:
# (1000, 16)
# Tipos de datos:
# {'created_at': 'object',
#  'deleted_at': 'object',
#  'doc_format_type_id': 'int64',
#  'documented_at': 'object',
#  'documented_id': 'float64',
#  'documented_type': 'object',
#  'firebase_token_id': 'float64',
#  'id': 'int64',
#  'name': 'object',
#  'pet_id': 'int64',
#  'required_signature': 'int64',
#  'signature_at': 'object',
#  'updated_at': 'object',
#  'user_id': 'int64',
#  'vet_id': 'int64',
#  'waiting_room_shift_id': 'float64'}
# Columnas:
# ['id',
#  'vet_id',
#  'pet_id',
#  'user_id',
#  'firebase_token_id',
#  'doc_format_type_id',
#  'documented_id',
#  'documented_type',
#  'documented_at',
#  'name',
#  'required_signature',
#  'signature_at',
#  'waiting_room_shift_id',
#  'created_at',
#  'updated_at',
#  'deleted_at']
# Valores nulos:
# {'created_at': 0,
#  'deleted_at': 961,
#  'doc_format_type_id': 0,
#  'documented_at': 0,
#  'documented_id': 940,
#  'documented_type': 940,
#  'firebase_token_id': 986,
#  'id': 0,
#  'name': 0,
#  'pet_id': 0,
#  'required_signature': 0,
#  'signature_at': 361,
#  'updated_at': 0,
#  'user_id': 0,
#  'vet_id': 0,
#  'waiting_room_shift_id': 996}
# Estadísticas de tendencia central:
# {'doc_format_type_id': {'media': 25441.433, 'mediana': 26459.0, 'nulos': 0},
#  'documented_id': {'media': 360617.01666666666,
#                    'mediana': 260168.0,
#                    'nulos': 940},
#  'firebase_token_id': {'media': 112874.0, 'mediana': 117195.0, 'nulos': 986},
#  'id': {'media': 224425.5, 'mediana': 224425.5, 'nulos': 0},
#  'pet_id': {'media': 1599818.572, 'mediana': 1947833.0, 'nulos': 0},
#  'required_signature': {'media': 0.943, 'mediana': 1.0, 'nulos': 0},
#  'user_id': {'media': 12904.155, 'mediana': 13510.0, 'nulos': 0},
#  'vet_id': {'media': 5686.814, 'mediana': 4476.5, 'nulos': 0},
#  'waiting_room_shift_id': {'media': 23019.25, 'mediana': 23023.5, 'nulos': 996}}
# Ejemplo de los primeros 5 registros:
# {'created_at': {0: '2025-05-28 12:57:05',
#                 1: '2025-05-28 12:57:03',
#                 2: '2025-05-28 12:56:05',
#                 3: '2025-05-28 12:55:20',
#                 4: '2025-05-28 12:54:16'},
#  'deleted_at': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'doc_format_type_id': {0: 43461, 1: 18312, 2: 25372, 3: 7876, 4: 7876},
#  'documented_at': {0: '2025-05-28 12:57:05',
#                    1: '2025-05-28 12:57:03',
#                    2: '2025-05-28 12:56:05',
#                    3: '2025-05-28 12:55:20',
#                    4: '2025-05-28 12:54:16'},
#  'documented_id': {0: 260407.0, 1: 260406.0, 2: nan, 3: nan, 4: nan},
#  'documented_type': {0: 'App\\Models\\Spa',
#                      1: 'App\\Models\\Spa',
#                      2: nan,
#                      3: nan,
#                      4: nan},
#  'firebase_token_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'id': {0: 224925, 1: 224924, 2: 224923, 3: 224922, 4: 224921},
#  'name': {0: 'CONSENTIMIENTO PELUQUERIA',
#           1: 'AUTORIZACION PELUQUERIA',
#           2: 'Consentimiento informado',
#           3: 'CONSENTIMIENTO INFORMADO DE SERVICIO DE PELUQUERÍA',
#           4: 'CONSENTIMIENTO INFORMADO DE SERVICIO DE PELUQUERÍA'},
#  'pet_id': {0: 1613171, 1: 1704034, 2: 1604238, 3: 1978001, 4: 1977939},
#  'required_signature': {0: 1, 1: 1, 2: 1, 3: 1, 4: 1},
#  'signature_at': {0: '2025-05-28 12:58:24',
#                   1: '2025-05-28 12:57:30',
#                   2: nan,
#                   3: '2025-05-28 13:04:08',
#                   4: nan},
#  'updated_at': {0: '2025-05-28 12:58:24',
#                 1: '2025-05-28 12:57:30',
#                 2: '2025-05-28 12:56:05',
#                 3: '2025-05-28 13:04:08',
#                 4: '2025-05-28 12:54:16'},
#  'user_id': {0: 21558, 1: 9837, 2: 13072, 3: 9704, 4: 9704},
#  'vet_id': {0: 2851, 1: 2773, 2: 8379, 3: 2640, 4: 2640},
#  'waiting_room_shift_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan}}

# %% [markdown]
# Nota: Waiting_Id se puede eliminar- Firebase_token_id Revisar que es
# No le ve importancia para el estudio

# %% [markdown]
# **Examenes_cabecera**

# %%
##Forma
print("Forma del DataFrame:")
pprint(resultados_analisis["examenes_cabecera.xlsx"]["Sheet1"]["forma"])
##Tipos de datos
print("Tipos de datos:")
pprint(resultados_analisis["examenes_cabecera.xlsx"]["Sheet1"]["tipos_datos"])
##Columnas
print("Columnas:")
pprint(resultados_analisis["examenes_cabecera.xlsx"]["Sheet1"]["columnas"])
##Valores nulos
print("Valores nulos:")
pprint(resultados_analisis["examenes_cabecera.xlsx"]["Sheet1"]["valores_nulos"])
##Estadisticas de tendencia central
print("Estadísticas de tendencia central:")
pprint(resultados_analisis["examenes_cabecera.xlsx"]["Sheet1"]["estadisticas_tendencia_central"])
##Muestra de los primeros 5 registros
print("Ejemplo de los primeros 5 registros:")
pprint(resultados_analisis["examenes_cabecera.xlsx"]["Sheet1"]["ejemplo"])
# Out:
# Forma del DataFrame:
# (1000, 13)
# Tipos de datos:
# {'created_at': 'object',
#  'deleted_at': 'object',
#  'diagnosis': 'object',
#  'dx': 'object',
#  'exam_date': 'object',
#  'id': 'int64',
#  'laboratories_id': 'float64',
#  'laboratories_type': 'float64',
#  'pet_id': 'int64',
#  'updated_at': 'object',
#  'user_id': 'int64',
#  'vet_id': 'int64',
#  'waiting_room_shift_id': 'float64'}
# Columnas:
# ['id',
#  'pet_id',
#  'user_id',
#  'laboratories_id',
#  'laboratories_type',
#  'vet_id',
#  'exam_date',
#  'diagnosis',
#  'dx',
#  'waiting_room_shift_id',
#  'created_at',
#  'updated_at',
#  'deleted_at']
# Valores nulos:
# {'created_at': 0,
#  'deleted_at': 993,
#  'diagnosis': 46,
#  'dx': 999,
#  'exam_date': 0,
#  'id': 0,
#  'laboratories_id': 1000,
#  'laboratories_type': 1000,
#  'pet_id': 0,
#  'updated_at': 0,
#  'user_id': 0,
#  'vet_id': 0,
#  'waiting_room_shift_id': 1000}
# Estadísticas de tendencia central:
# {'id': {'media': 572754.5, 'mediana': 572754.5, 'nulos': 0},
#  'laboratories_id': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'laboratories_type': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'pet_id': {'media': 1555679.816, 'mediana': 1923619.0, 'nulos': 0},
#  'user_id': {'media': 13775.002, 'mediana': 16340.0, 'nulos': 0},
#  'vet_id': {'media': 6886.099, 'mediana': 6240.0, 'nulos': 0},
#  'waiting_room_shift_id': {'media': nan, 'mediana': nan, 'nulos': 1000}}
# Ejemplo de los primeros 5 registros:
# {'created_at': {0: '2025-05-28 12:55:49',
#                 1: '2025-05-28 12:54:28',
#                 2: '2025-05-28 12:54:02',
#                 3: '2025-05-28 11:53:55',
#                 4: '2025-05-28 12:53:30'},
#  'deleted_at': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'diagnosis': {0: 'HISTOPATOLOGIA',
#                1: 'HISTOPATOLOGIA',
#                2: '.',
#                3: 'Seguimiento',
#                4: 'EXAMENES CONTROL PRE ANESTESICOS RESONANCIA.\n'
#                   'HALLAZGOS:\n'
#                   'CH: LEUCOPENIA, TROMBOCITOPENIA (LEVE).\n'
#                   'BIOQUIMICAS: ALT ELEVADA 315.9'},
#  'dx': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'exam_date': {0: '2025-05-28',
#                1: '2025-05-28',
#                2: '2025-05-28',
#                3: '2025-05-28',
#                4: '2025-05-27'},
#  'id': {0: 573254, 1: 573253, 2: 573252, 3: 573251, 4: 573250},
#  'laboratories_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'laboratories_type': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'pet_id': {0: 1808561, 1: 1615953, 2: 1978025, 3: 1049582, 4: 1946027},
#  'updated_at': {0: '2025-05-28 12:55:49',
#                 1: '2025-05-28 12:54:28',
#                 2: '2025-05-28 12:54:02',
#                 3: '2025-05-28 11:53:55',
#                 4: '2025-05-28 12:53:30'},
#  'user_id': {0: 20238, 1: 20238, 2: 15087, 3: 4962, 4: 11242},
#  'vet_id': {0: 13444, 1: 13444, 2: 9856, 3: 3132, 4: 1141},
#  'waiting_room_shift_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan}}

# %% [markdown]
# Nota: Lo importante es el diagnostico
# No se sabe que es el dx

# %% [markdown]
# **Examenes Items**

# %%
##Forma
print("Forma del DataFrame:")
pprint(resultados_analisis["examenes_items.xlsx"]["Sheet1"]["forma"])
##Tipos de datos
print("Tipos de datos:")
pprint(resultados_analisis["examenes_items.xlsx"]["Sheet1"]["tipos_datos"])
##Columnas
print("Columnas:")
pprint(resultados_analisis["examenes_items.xlsx"]["Sheet1"]["columnas"])
##Valores nulos
print("Valores nulos:")
pprint(resultados_analisis["examenes_items.xlsx"]["Sheet1"]["valores_nulos"])
##Estadisticas de tendencia central
print("Estadísticas de tendencia central:")
pprint(resultados_analisis["examenes_items.xlsx"]["Sheet1"]["estadisticas_tendencia_central"])
##Muestra de los primeros 5 registros
print("Ejemplo de los primeros 5 registros:")
pprint(resultados_analisis["examenes_items.xlsx"]["Sheet1"]["ejemplo"])
# Out:
# Forma del DataFrame:
# (1000, 10)
# Tipos de datos:
# {'created_at': 'object',
#  'deleted_at': 'object',
#  'file': 'object',
#  'id': 'int64',
#  'laboratory_id': 'int64',
#  'laboratory_test_id': 'int64',
#  'order_item_id': 'float64',
#  'quantity': 'int64',
#  'updated_at': 'object',
#  'user_id': 'int64'}
# Columnas:
# ['id',
#  'laboratory_id',
#  'user_id',
#  'laboratory_test_id',
#  'order_item_id',
#  'quantity',
#  'file',
#  'created_at',
#  'updated_at',
#  'deleted_at']
# Valores nulos:
# {'created_at': 0,
#  'deleted_at': 998,
#  'file': 133,
#  'id': 0,
#  'laboratory_id': 0,
#  'laboratory_test_id': 0,
#  'order_item_id': 1000,
#  'quantity': 0,
#  'updated_at': 0,
#  'user_id': 0}
# Estadísticas de tendencia central:
# {'id': {'media': 708429.5, 'mediana': 708429.5, 'nulos': 0},
#  'laboratory_id': {'media': 572859.806, 'mediana': 572883.0, 'nulos': 0},
#  'laboratory_test_id': {'media': 1801168.622, 'mediana': 2053119.5, 'nulos': 0},
#  'order_item_id': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'quantity': {'media': 1.0, 'mediana': 1.0, 'nulos': 0},
#  'user_id': {'media': 13096.752, 'mediana': 15087.0, 'nulos': 0}}
# Ejemplo de los primeros 5 registros:
# {'created_at': {0: '2025-05-28 12:55:49',
#                 1: '2025-05-28 12:54:28',
#                 2: '2025-05-28 12:54:02',
#                 3: '2025-05-28 11:53:55',
#                 4: '2025-05-28 12:53:30'},
#  'deleted_at': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'file': {0: '{"name": "MAYA HISTOPATOLOGIA SURISADDAI ARDILA.pdf", "path": '
#              '"VetFiles/13444/LaboratoryExam/QmbOx9uH8n75pXO4BNPM6bJrWpGdMRAPzrQT6lWp.pdf"}',
#           1: '{"name": "KEILY HISTOPATOLOGIA ALEJANDRO OROZCO.pdf", "path": '
#              '"VetFiles/13444/LaboratoryExam/nz8uxDnENnsfmsSr8uIHdAQH0oCJF8ufOBloQCdd.pdf"}',
#           2: '{"name": "IMG-20250528-WA0033.jpg", "path": '
#              '"VetFiles/9856/LaboratoryExam/ntU5QkJA9ibOS75H9bbRmPMm0v2noRZHQGjU39X4.jpg"}',
#           3: '{"name": "GINA-MONTIEL-2025-05-28-0953.pdf", "path": '
#              '"VetFiles/3132/LaboratoryExam/jrv9x5QJMG5p33SDFmgBOCngj0DzJvy08TVjhXCV.pdf"}',
#           4: '{"name": "QUIMICA SANGUINEA CANINO YAKO LOBO 270525.pdf", '
#              '"path": '
#              '"VetFiles/1141/LaboratoryExam/08Pgz4hrvdrO3C15sGAA72jmgOUaj4LIqmG5Lb1P.pdf"}'},
#  'id': {0: 708929, 1: 708928, 2: 708927, 3: 708926, 4: 708925},
#  'laboratory_id': {0: 573254, 1: 573253, 2: 573252, 3: 573251, 4: 573250},
#  'laboratory_test_id': {0: 2857894,
#                         1: 2857894,
#                         2: 2016160,
#                         3: 650836,
#                         4: 1997077},
#  'order_item_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'quantity': {0: 1, 1: 1, 2: 1, 3: 1, 4: 1},
#  'updated_at': {0: '2025-05-28 12:55:49',
#                 1: '2025-05-28 12:54:28',
#                 2: '2025-05-28 12:54:02',
#                 3: '2025-05-28 11:53:55',
#                 4: '2025-05-28 12:53:30'},
#  'user_id': {0: 20299, 1: 20227, 2: 15087, 3: 4962, 4: 11242}}

# %% [markdown]
# Nota: No veo informacion importante para minar
# Preguntar que es el id del test de laboratorio

# %% [markdown]
# **Formulas Cabecera**

# %%
##Forma
print("Forma del DataFrame:")
pprint(resultados_analisis["formulas_cabecera.xlsx"]["Sheet1"]["forma"])
##Tipos de datos
print("Tipos de datos:")
pprint(resultados_analisis["formulas_cabecera.xlsx"]["Sheet1"]["tipos_datos"])
##Columnas
print("Columnas:")
pprint(resultados_analisis["formulas_cabecera.xlsx"]["Sheet1"]["columnas"])
##Valores nulos
print("Valores nulos:")
pprint(resultados_analisis["formulas_cabecera.xlsx"]["Sheet1"]["valores_nulos"])
##Estadisticas de tendencia central
print("Estadísticas de tendencia central:")
pprint(resultados_analisis["formulas_cabecera.xlsx"]["Sheet1"]["estadisticas_tendencia_central"])
##Muestra de los primeros 5 registros
print("Ejemplo de los primeros 5 registros:")
pprint(resultados_analisis["formulas_cabecera.xlsx"]["Sheet1"]["ejemplo"])
# Out:
# Forma del DataFrame:
# (1000, 14)
# Tipos de datos:
# {'created_at': 'object',
#  'deleted_at': 'object',
#  'details': 'object',
#  'diagnosis': 'object',
#  'dx': 'object',
#  'id': 'int64',
#  'pet_id': 'int64',
#  'prescription': 'float64',
#  'prescription_at': 'object',
#  'raw_prescription': 'float64',
#  'updated_at': 'object',
#  'user_id': 'int64',
#  'vet_id': 'int64',
#  'waiting_room_shift_id': 'float64'}
# Columnas:
# ['id',
#  'pet_id',
#  'vet_id',
#  'user_id',
#  'prescription_at',
#  'diagnosis',
#  'raw_prescription',
#  'prescription',
#  'details',
#  'dx',
#  'waiting_room_shift_id',
#  'created_at',
#  'updated_at',
#  'deleted_at']
# Valores nulos:
# {'created_at': 0,
#  'deleted_at': 993,
#  'details': 1,
#  'diagnosis': 0,
#  'dx': 992,
#  'id': 0,
#  'pet_id': 0,
#  'prescription': 1000,
#  'prescription_at': 0,
#  'raw_prescription': 1000,
#  'updated_at': 0,
#  'user_id': 0,
#  'vet_id': 0,
#  'waiting_room_shift_id': 993}
# Estadísticas de tendencia central:
# {'id': {'media': 1412537.5, 'mediana': 1412537.5, 'nulos': 0},
#  'pet_id': {'media': 1612937.473, 'mediana': 1958516.0, 'nulos': 0},
#  'prescription': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'raw_prescription': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'user_id': {'media': 12066.172, 'mediana': 12586.0, 'nulos': 0},
#  'vet_id': {'media': 6654.925, 'mediana': 5804.0, 'nulos': 0},
#  'waiting_room_shift_id': {'media': 23039.285714285714,
#                            'mediana': 23044.0,
#                            'nulos': 993}}
# Ejemplo de los primeros 5 registros:
# {'created_at': {0: '2025-05-28 12:49:54',
#                 1: '2025-05-28 12:49:54',
#                 2: '2025-05-28 12:49:21',
#                 3: '2025-05-28 12:49:08',
#                 4: '2025-05-28 12:49:03'},
#  'deleted_at': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'details': {0: '- CONTROL EL DIA 4/06/2025 A LAS 10.30AM\n'
#                 '- RETIRO DE PUNTOS EL DIA 11/05/2025 A LAS 10:30 AM (SEGUN LA '
#                 'EVOLUCION DE LA PACIENTE).\n'
#                 '- USO DE BODY QUIRURGICO CONSTANTE POR 15 DIAS.\n'
#                 '- OFRECER DIETA BLANDA POR 3 DIAS (LATA DE HILLS A/D O ROYAL '
#                 'CANIN SHIH-TZU).\n'
#                 '- SEGUN LOS RESULTADOS DEL EXAMEN SANGUINEO SE COMPLEMENTARA '
#                 'LA FORMULA MEDICA.',
#              1: 'tener en un lugara cerrado \ntener con collar isabelino',
#              2: '- MEDICACIÓN APARTIR DE MAÑANA.\n'
#                 '- USO DE COLLAR ISABELINO OBLIGATORIO Y PERMANENTE HASTA EL '
#                 'RETIRO DE PUNTOS.\n'
#                 '- RETIRO DE PUNTOS EN 10 DÍAS.\n'
#                 '\n'
#                 '- Puede presentarse 1 o 2 episodios de vómito durante las '
#                 'primeras 24 horas postquirúrgicas que pueden considerarse '
#                 'normales por efecto residual de anestesia.\n'
#                 '- El paciente debe permanecer calientito, recuerde que la '
#                 'anestesia baja la temperatura corporal y la capacidad de '
#                 'regularla.\n'
#                 '- No obligue a comer/recibir agua durante las primeras 12 '
#                 'horas postquirúrgicas.\n'
#                 '- Ante cualquier eventualidad comunicarse o acudir con la '
#                 'clínica de inmediato.\n'
#                 '- CITA DE CONTROL DENTRO DE 3 DÍAS.',
#              3: nan,
#              4: 'SE RECOMIENDA TRAER A REVISIÓN EL DÍA SÁBADO 2-10PM\n'
#                 'SE RECOMIENDA DISMINUIR MOVIMIENTOS BRUSCOS'},
#  'diagnosis': {0: '- OVARIOHISTERECTOMIA',
#                1: 'suturacion',
#                2: 'PACIENTE POSTQUIRURGICO DE OVH ELECTIVA',
#                3: 'Disbiosis',
#                4: 'TRAUMA POR GOLPE'},
#  'dx': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'id': {0: 1413037, 1: 1413036, 2: 1413035, 3: 1413034, 4: 1413033},
#  'pet_id': {0: 1977722, 1: 1977392, 2: 1977396, 3: 1732346, 4: 1978058},
#  'prescription': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'prescription_at': {0: '2025-05-28',
#                      1: '2025-05-28',
#                      2: '2025-05-28',
#                      3: '2025-05-28',
#                      4: '2025-05-28'},
#  'raw_prescription': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'updated_at': {0: '2025-05-28 12:49:54',
#                 1: '2025-05-28 12:49:54',
#                 2: '2025-05-28 12:49:21',
#                 3: '2025-05-28 12:49:08',
#                 4: '2025-05-28 12:49:03'},
#  'user_id': {0: 13072, 1: 11081, 2: 676, 3: 9314, 4: 23660},
#  'vet_id': {0: 8379, 1: 12435, 2: 1223, 3: 5850, 4: 15608},
#  'waiting_room_shift_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan}}

# %% [markdown]
# Nota: prescripcion y raw_prescripcion no tiene informacion. La informacion esta en details y diagnosis

# %% [markdown]
# **Formulas Items**

# %%
##Forma
print("Forma del DataFrame:")
pprint(resultados_analisis["formulas_cabecera.xlsx"]["Sheet1"]["forma"])
##Tipos de datos
print("Tipos de datos:")
pprint(resultados_analisis["formulas_cabecera.xlsx"]["Sheet1"]["tipos_datos"])
##Columnas
print("Columnas:")
pprint(resultados_analisis["formulas_cabecera.xlsx"]["Sheet1"]["columnas"])
##Valores nulos
print("Valores nulos:")
pprint(resultados_analisis["formulas_cabecera.xlsx"]["Sheet1"]["valores_nulos"])
##Estadisticas de tendencia central
print("Estadísticas de tendencia central:")
pprint(resultados_analisis["formulas_cabecera.xlsx"]["Sheet1"]["estadisticas_tendencia_central"])
##Muestra de los primeros 5 registros
print("Ejemplo de los primeros 5 registros:")
pprint(resultados_analisis["formulas_cabecera.xlsx"]["Sheet1"]["ejemplo"])
# Out:
# Forma del DataFrame:
# (1000, 14)
# Tipos de datos:
# {'created_at': 'object',
#  'deleted_at': 'object',
#  'details': 'object',
#  'diagnosis': 'object',
#  'dx': 'object',
#  'id': 'int64',
#  'pet_id': 'int64',
#  'prescription': 'float64',
#  'prescription_at': 'object',
#  'raw_prescription': 'float64',
#  'updated_at': 'object',
#  'user_id': 'int64',
#  'vet_id': 'int64',
#  'waiting_room_shift_id': 'float64'}
# Columnas:
# ['id',
#  'pet_id',
#  'vet_id',
#  'user_id',
#  'prescription_at',
#  'diagnosis',
#  'raw_prescription',
#  'prescription',
#  'details',
#  'dx',
#  'waiting_room_shift_id',
#  'created_at',
#  'updated_at',
#  'deleted_at']
# Valores nulos:
# {'created_at': 0,
#  'deleted_at': 993,
#  'details': 1,
#  'diagnosis': 0,
#  'dx': 992,
#  'id': 0,
#  'pet_id': 0,
#  'prescription': 1000,
#  'prescription_at': 0,
#  'raw_prescription': 1000,
#  'updated_at': 0,
#  'user_id': 0,
#  'vet_id': 0,
#  'waiting_room_shift_id': 993}
# Estadísticas de tendencia central:
# {'id': {'media': 1412537.5, 'mediana': 1412537.5, 'nulos': 0},
#  'pet_id': {'media': 1612937.473, 'mediana': 1958516.0, 'nulos': 0},
#  'prescription': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'raw_prescription': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'user_id': {'media': 12066.172, 'mediana': 12586.0, 'nulos': 0},
#  'vet_id': {'media': 6654.925, 'mediana': 5804.0, 'nulos': 0},
#  'waiting_room_shift_id': {'media': 23039.285714285714,
#                            'mediana': 23044.0,
#                            'nulos': 993}}
# Ejemplo de los primeros 5 registros:
# {'created_at': {0: '2025-05-28 12:49:54',
#                 1: '2025-05-28 12:49:54',
#                 2: '2025-05-28 12:49:21',
#                 3: '2025-05-28 12:49:08',
#                 4: '2025-05-28 12:49:03'},
#  'deleted_at': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'details': {0: '- CONTROL EL DIA 4/06/2025 A LAS 10.30AM\n'
#                 '- RETIRO DE PUNTOS EL DIA 11/05/2025 A LAS 10:30 AM (SEGUN LA '
#                 'EVOLUCION DE LA PACIENTE).\n'
#                 '- USO DE BODY QUIRURGICO CONSTANTE POR 15 DIAS.\n'
#                 '- OFRECER DIETA BLANDA POR 3 DIAS (LATA DE HILLS A/D O ROYAL '
#                 'CANIN SHIH-TZU).\n'
#                 '- SEGUN LOS RESULTADOS DEL EXAMEN SANGUINEO SE COMPLEMENTARA '
#                 'LA FORMULA MEDICA.',
#              1: 'tener en un lugara cerrado \ntener con collar isabelino',
#              2: '- MEDICACIÓN APARTIR DE MAÑANA.\n'
#                 '- USO DE COLLAR ISABELINO OBLIGATORIO Y PERMANENTE HASTA EL '
#                 'RETIRO DE PUNTOS.\n'
#                 '- RETIRO DE PUNTOS EN 10 DÍAS.\n'
#                 '\n'
#                 '- Puede presentarse 1 o 2 episodios de vómito durante las '
#                 'primeras 24 horas postquirúrgicas que pueden considerarse '
#                 'normales por efecto residual de anestesia.\n'
#                 '- El paciente debe permanecer calientito, recuerde que la '
#                 'anestesia baja la temperatura corporal y la capacidad de '
#                 'regularla.\n'
#                 '- No obligue a comer/recibir agua durante las primeras 12 '
#                 'horas postquirúrgicas.\n'
#                 '- Ante cualquier eventualidad comunicarse o acudir con la '
#                 'clínica de inmediato.\n'
#                 '- CITA DE CONTROL DENTRO DE 3 DÍAS.',
#              3: nan,
#              4: 'SE RECOMIENDA TRAER A REVISIÓN EL DÍA SÁBADO 2-10PM\n'
#                 'SE RECOMIENDA DISMINUIR MOVIMIENTOS BRUSCOS'},
#  'diagnosis': {0: '- OVARIOHISTERECTOMIA',
#                1: 'suturacion',
#                2: 'PACIENTE POSTQUIRURGICO DE OVH ELECTIVA',
#                3: 'Disbiosis',
#                4: 'TRAUMA POR GOLPE'},
#  'dx': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'id': {0: 1413037, 1: 1413036, 2: 1413035, 3: 1413034, 4: 1413033},
#  'pet_id': {0: 1977722, 1: 1977392, 2: 1977396, 3: 1732346, 4: 1978058},
#  'prescription': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'prescription_at': {0: '2025-05-28',
#                      1: '2025-05-28',
#                      2: '2025-05-28',
#                      3: '2025-05-28',
#                      4: '2025-05-28'},
#  'raw_prescription': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'updated_at': {0: '2025-05-28 12:49:54',
#                 1: '2025-05-28 12:49:54',
#                 2: '2025-05-28 12:49:21',
#                 3: '2025-05-28 12:49:08',
#                 4: '2025-05-28 12:49:03'},
#  'user_id': {0: 13072, 1: 11081, 2: 676, 3: 9314, 4: 23660},
#  'vet_id': {0: 8379, 1: 12435, 2: 1223, 3: 5850, 4: 15608},
#  'waiting_room_shift_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan}}

# %% [markdown]
# Nota: Poca información relevante

# %% [markdown]
# **Guarderia**

# %%
##Forma
print("Forma del DataFrame:")
pprint(resultados_analisis["guarderia.xlsx"]["Sheet1"]["forma"])
##Tipos de datos
print("Tipos de datos:")
pprint(resultados_analisis["guarderia.xlsx"]["Sheet1"]["tipos_datos"])
##Columnas
print("Columnas:")
pprint(resultados_analisis["guarderia.xlsx"]["Sheet1"]["columnas"])
##Valores nulos
print("Valores nulos:")
pprint(resultados_analisis["guarderia.xlsx"]["Sheet1"]["valores_nulos"])
##Estadisticas de tendencia central
print("Estadísticas de tendencia central:")
pprint(resultados_analisis["guarderia.xlsx"]["Sheet1"]["estadisticas_tendencia_central"])
##Muestra de los primeros 5 registros
print("Ejemplo de los primeros 5 registros:")
pprint(resultados_analisis["guarderia.xlsx"]["Sheet1"]["ejemplo"])
# Out:
# Forma del DataFrame:
# (1000, 14)
# Tipos de datos:
# {'admission_date': 'object',
#  'created_at': 'object',
#  'deleted_at': 'object',
#  'discharge_date': 'object',
#  'id': 'int64',
#  'objects': 'object',
#  'observations': 'object',
#  'pet_id': 'int64',
#  'quantity': 'object',
#  'type': 'object',
#  'updated_at': 'object',
#  'user_id': 'int64',
#  'vet_id': 'int64',
#  'waiting_room_shift_id': 'float64'}
# Columnas:
# ['id',
#  'pet_id',
#  'vet_id',
#  'user_id',
#  'admission_date',
#  'discharge_date',
#  'type',
#  'quantity',
#  'objects',
#  'observations',
#  'waiting_room_shift_id',
#  'created_at',
#  'updated_at',
#  'deleted_at']
# Valores nulos:
# {'admission_date': 0,
#  'created_at': 0,
#  'deleted_at': 985,
#  'discharge_date': 176,
#  'id': 0,
#  'objects': 428,
#  'observations': 482,
#  'pet_id': 0,
#  'quantity': 3,
#  'type': 4,
#  'updated_at': 0,
#  'user_id': 0,
#  'vet_id': 0,
#  'waiting_room_shift_id': 1000}
# Estadísticas de tendencia central:
# {'id': {'media': 7359.5, 'mediana': 7359.5, 'nulos': 0},
#  'pet_id': {'media': 1247040.052, 'mediana': 1392002.5, 'nulos': 0},
#  'user_id': {'media': 14400.084, 'mediana': 17713.0, 'nulos': 0},
#  'vet_id': {'media': 5819.246, 'mediana': 4016.0, 'nulos': 0},
#  'waiting_room_shift_id': {'media': nan, 'mediana': nan, 'nulos': 1000}}
# Ejemplo de los primeros 5 registros:
# {'admission_date': {0: '2025-05-27 10:00:00',
#                     1: '2025-05-26 07:00:00',
#                     2: '2025-05-27 07:00:00',
#                     3: '2025-05-27 07:00:00',
#                     4: '2025-05-08 08:01:00'},
#  'created_at': {0: '2025-05-28 12:57:33',
#                 1: '2025-05-27 15:55:37',
#                 2: '2025-05-27 15:08:57',
#                 3: '2025-05-27 15:08:01',
#                 4: '2025-05-27 13:17:57'},
#  'deleted_at': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'discharge_date': {0: nan,
#                     1: '2025-05-27 16:00:00',
#                     2: '2025-05-27 16:00:00',
#                     3: '2025-05-27 16:00:00',
#                     4: '2025-06-01 08:00:00'},
#  'id': {0: 7859, 1: 7858, 2: 7857, 3: 7856, 4: 7855},
#  'objects': {0: nan, 1: nan, 2: nan, 3: nan, 4: 'Ninguno'},
#  'observations': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'pet_id': {0: 1101719, 1: 878535, 2: 1196329, 3: 1874557, 4: 1882243},
#  'quantity': {0: 'porcion',
#               1: '2 veces al dia',
#               2: '3 veces al dia',
#               3: '3 veces al dia',
#               4: 'Alta'},
#  'type': {0: 'dog', 1: 'concentrado', 2: 'Dieta', 3: 'Dieta', 4: 'Casera'},
#  'updated_at': {0: '2025-05-28 12:57:33',
#                 1: '2025-05-27 15:55:37',
#                 2: '2025-05-27 15:08:57',
#                 3: '2025-05-27 15:08:01',
#                 4: '2025-05-27 13:17:57'},
#  'user_id': {0: 2872, 1: 19389, 2: 19389, 3: 19389, 4: 21735},
#  'vet_id': {0: 1741, 1: 2250, 2: 2250, 3: 2250, 4: 14630},
#  'waiting_room_shift_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan}}

# %% [markdown]
# Nota: La informaciín valiosa es en quantity (Parece ser de comida)

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ***Análisis exploratorio en el que se estudia el tipo de dato de cada columna de las hojas de excel asignadas y se establece el significado cualitativo de cada columna***

# %% [markdown]
# ##### Propietarios .xlsx

# %%
##Forma
print("Forma (size) del DataFrame:")
pprint(resultados_analisis["propietarios.xlsx"]["Sheet1"]["forma"])
##Tipos de datos
print("Tipos de datos:")
pprint(resultados_analisis["propietarios.xlsx"]["Sheet1"]["tipos_datos"])
##Columnas
print("Columnas:")
pprint(resultados_analisis["propietarios.xlsx"]["Sheet1"]["columnas"])
##Valores nulos
print("Valores nulos:")
pprint(resultados_analisis["propietarios.xlsx"]["Sheet1"]["valores_nulos"])
##Estadisticas de tendencia central
print("Estadísticas de tendencia central:")
pprint(resultados_analisis["propietarios.xlsx"]["Sheet1"]["estadisticas_tendencia_central"])
##Muestra de los primeros 5 registros
print("Ejemplo de los primeros 5 registros:")
pprint(resultados_analisis["propietarios.xlsx"]["Sheet1"]["ejemplo"])
# Out:
# Forma (size) del DataFrame:
# (1000, 19)
# Tipos de datos:
# {'address (mask)': 'object',
#  'city': 'object',
#  'conctact (mask)': 'object',
#  'country': 'object',
#  'created_at': 'object',
#  'deleted_at': 'float64',
#  'email (mask)': 'object',
#  'habeas_at': 'object',
#  'id': 'int64',
#  'ident_type': 'object',
#  'kind_person': 'object',
#  'mobile (mask)': 'object',
#  'name (mask)': 'object',
#  'number_doc (mask)': 'object',
#  'phone (mask)': 'object',
#  'phone2 (mask)': 'object',
#  'regime': 'object',
#  'region': 'object',
#  'updated_at': 'object'}
# Columnas:
# ['id',
#  'name (mask)',
#  'ident_type',
#  'number_doc (mask)',
#  'phone (mask)',
#  'phone2 (mask)',
#  'mobile (mask)',
#  'email (mask)',
#  'address (mask)',
#  'city',
#  'region',
#  'country',
#  'conctact (mask)',
#  'kind_person',
#  'regime',
#  'habeas_at',
#  'created_at',
#  'updated_at',
#  'deleted_at']
# Valores nulos:
# {'address (mask)': 0,
#  'city': 9,
#  'conctact (mask)': 387,
#  'country': 10,
#  'created_at': 0,
#  'deleted_at': 1000,
#  'email (mask)': 0,
#  'habeas_at': 9,
#  'id': 0,
#  'ident_type': 0,
#  'kind_person': 0,
#  'mobile (mask)': 0,
#  'name (mask)': 0,
#  'number_doc (mask)': 0,
#  'phone (mask)': 0,
#  'phone2 (mask)': 0,
#  'regime': 0,
#  'region': 10,
#  'updated_at': 0}
# Estadísticas de tendencia central:
# {'deleted_at': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'id': {'media': 1488020.5, 'mediana': 1488020.5, 'nulos': 0}}
# Ejemplo de los primeros 5 registros:
# {'address (mask)': {0: 'supia',
#                     1: 'Zapan*************************',
#                     2: 'El cl**************',
#                     3: 'no re*****',
#                     4: 'calle****************************'},
#  'city': {0: 'Supía',
#           1: 'Dosquebradas',
#           2: 'Provincia de Cartagena',
#           3: 'Bogotá',
#           4: 'Tuluá'},
#  'conctact (mask)': {0: nan,
#                      1: 'J***** e******',
#                      2: nan,
#                      3: 'D****** G********',
#                      4: 'S***** R******'},
#  'country': {0: 'Colombia',
#              1: 'Colombia',
#              2: 'Colombia',
#              3: 'Colombia',
#              4: 'Colombia'},
#  'created_at': {0: '2025-05-28 11:17:43',
#                 1: '2025-05-28 11:17:40',
#                 2: '2025-05-28 11:17:13',
#                 3: '2025-05-28 11:17:11',
#                 4: '2025-05-28 11:16:42'},
#  'deleted_at': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'email (mask)': {0: '***',
#                   1: '***',
#                   2: 'tan***********@hotmail.com',
#                   3: 'jin******@outlook.com',
#                   4: '***'},
#  'habeas_at': {0: '2025-05-28 11:17:43',
#                1: '2025-05-28 11:17:40',
#                2: '2025-05-28 11:17:13',
#                3: '2025-05-28 11:17:11',
#                4: '2025-05-28 11:16:42'},
#  'id': {0: 1488520, 1: 1488519, 2: 1488518, 3: 1488517, 4: 1488516},
#  'ident_type': {0: 'mobile', 1: 'cc', 2: 'cc', 3: 'cc', 4: 'cc'},
#  'kind_person': {0: 'PERSON_ENTITY',
#                  1: 'PERSON_ENTITY',
#                  2: 'PERSON_ENTITY',
#                  3: 'PERSON_ENTITY',
#                  4: 'PERSON_ENTITY'},
#  'mobile (mask)': {0: '+5732********',
#                    1: '+5731********',
#                    2: '+5730********',
#                    3: '+5731********',
#                    4: '+5732********'},
#  'name (mask)': {0: 'j******* b*****',
#                  1: 'A******* r************',
#                  2: 'T**** R********',
#                  3: 'L**** G********',
#                  4: 'S***** R******'},
#  'number_doc (mask)': {0: '+57**********',
#                        1: '340*****',
#                        2: '114*******',
#                        3: '102*******',
#                        4: '943*****'},
#  'phone (mask)': {0: '+5732********',
#                   1: '+5731********',
#                   2: '+5730********',
#                   3: '31428*****',
#                   4: '+57 3**********'},
#  'phone2 (mask)': {0: '+5732********',
#                    1: '31178*****',
#                    2: '+5730********',
#                    3: '31421*****',
#                    4: '+57 3**********'},
#  'regime': {0: 'SIMPLIFIED_REGIME',
#             1: 'SIMPLIFIED_REGIME',
#             2: 'SIMPLIFIED_REGIME',
#             3: 'SIMPLIFIED_REGIME',
#             4: 'SIMPLIFIED_REGIME'},
#  'region': {0: 'Caldas',
#             1: 'Risaralda',
#             2: 'Bolívar',
#             3: 'Bogotá',
#             4: 'Valle del Cauca'},
#  'updated_at': {0: '2025-05-28 11:17:43',
#                 1: '2025-05-28 11:17:40',
#                 2: '2025-05-28 11:17:13',
#                 3: '2025-05-28 11:17:11',
#                 4: '2025-05-28 11:16:42'}}

# %% [markdown]
# - Eliminar: deleted_at (100% nulos).
#
# - Revisar o decidir según necesidad: conctact (mask) (38.7% nulos), phone2 (mask), number_doc (mask).
#
# - Posible imputación: city, region, habeas_at.

# %% [markdown]
# ##### hospitalizaciones.xlsx

# %%
##Forma
print("Forma (size) del DataFrame:")
pprint(resultados_analisis["hospitalizaciones.xlsx"]["Sheet1"]["forma"])
##Tipos de datos
print("Tipos de datos:")
pprint(resultados_analisis["hospitalizaciones.xlsx"]["Sheet1"]["tipos_datos"])
##Columnas
print("Columnas:")
pprint(resultados_analisis["hospitalizaciones.xlsx"]["Sheet1"]["columnas"])
##Valores nulos
print("Valores nulos:")
pprint(resultados_analisis["hospitalizaciones.xlsx"]["Sheet1"]["valores_nulos"])
##Estadisticas de tendencia central
print("Estadísticas de tendencia central:")
pprint(resultados_analisis["hospitalizaciones.xlsx"]["Sheet1"]["estadisticas_tendencia_central"])
##Muestra de los primeros 5 registros
print("Ejemplo de los primeros 5 registros:")
pprint(resultados_analisis["hospitalizaciones.xlsx"]["Sheet1"]["ejemplo"])
# Out:
# Forma (size) del DataFrame:
# (1000, 14)
# Tipos de datos:
# {'admission_date': 'object',
#  'created_at': 'object',
#  'deleted_at': 'object',
#  'details': 'object',
#  'discharge_date': 'object',
#  'dx': 'object',
#  'hospital_care_type_id': 'int64',
#  'id': 'int64',
#  'pet_id': 'int64',
#  'reason': 'object',
#  'updated_at': 'object',
#  'user_id': 'int64',
#  'vet_id': 'int64',
#  'waiting_room_shift_id': 'float64'}
# Columnas:
# ['id',
#  'pet_id',
#  'vet_id',
#  'user_id',
#  'admission_date',
#  'discharge_date',
#  'hospital_care_type_id',
#  'reason',
#  'details',
#  'dx',
#  'waiting_room_shift_id',
#  'created_at',
#  'updated_at',
#  'deleted_at']
# Valores nulos:
# {'admission_date': 0,
#  'created_at': 0,
#  'deleted_at': 973,
#  'details': 509,
#  'discharge_date': 682,
#  'dx': 997,
#  'hospital_care_type_id': 0,
#  'id': 0,
#  'pet_id': 0,
#  'reason': 0,
#  'updated_at': 0,
#  'user_id': 0,
#  'vet_id': 0,
#  'waiting_room_shift_id': 997}
# Estadísticas de tendencia central:
# {'hospital_care_type_id': {'media': 4.806, 'mediana': 1.0, 'nulos': 0},
#  'id': {'media': 168080.5, 'mediana': 168080.5, 'nulos': 0},
#  'pet_id': {'media': 1689099.861, 'mediana': 1966374.0, 'nulos': 0},
#  'user_id': {'media': 16712.847, 'mediana': 19780.0, 'nulos': 0},
#  'vet_id': {'media': 7893.81, 'mediana': 8374.0, 'nulos': 0},
#  'waiting_room_shift_id': {'media': 22945.666666666668,
#                            'mediana': 23028.0,
#                            'nulos': 997}}
# Ejemplo de los primeros 5 registros:
# {'admission_date': {0: '2025-05-01 11:49:00',
#                     1: '2025-05-15 11:45:00',
#                     2: '2025-05-21 11:43:00',
#                     3: '2025-05-09 11:43:00',
#                     4: '2025-05-28 13:30:00'},
#  'created_at': {0: '2025-05-28 11:49:56',
#                 1: '2025-05-28 11:46:40',
#                 2: '2025-05-28 11:44:53',
#                 3: '2025-05-28 11:43:50',
#                 4: '2025-05-28 13:37:59'},
#  'deleted_at': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'details': {0: nan,
#              1: 'CERENIA 0.68ML\nINDIGEST 0.68ML\nTRAMAL 0.4ML\nRANI 0.3ML',
#              2: 'RANI 0.13MÑ\nHEPATIN FLUIDOS',
#              3: nan,
#              4: 'Tratamiento: \n'
#                 'Fluido terapia VT. 329 ml\n'
#                 'Reposición 109,6 ml/hrs.\n'
#                 'Mantenimiento 26,8 ml/hrs. VT. 188 ml\n'
#                 'Perdida 10,8 ml/hrs VT. 141 ml'},
#  'discharge_date': {0: nan,
#                     1: '2025-05-17 00:00:00',
#                     2: '2025-05-23 00:00:00',
#                     3: nan,
#                     4: nan},
#  'dx': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'hospital_care_type_id': {0: 43, 1: 1, 2: 1, 3: 43, 4: 1},
#  'id': {0: 168580, 1: 168579, 2: 168578, 3: 168577, 4: 168576},
#  'pet_id': {0: 1585104, 1: 403596, 2: 1965428, 3: 1059857, 4: 1977946},
#  'reason': {0: 'Profiláctico',
#             1: 'EX SANGRE ALTERADOS \nHALLAZGOS EN ULTRASONIDO',
#             2: 'DECAIDA \nFALLA RENAL',
#             3: 'Profiláctico',
#             4: 'Vomito y diarrea'},
#  'updated_at': {0: '2025-05-28 11:49:56',
#                 1: '2025-05-28 11:46:40',
#                 2: '2025-05-28 11:44:53',
#                 3: '2025-05-28 11:43:50',
#                 4: '2025-05-28 13:38:21'},
#  'user_id': {0: 8657, 1: 5491, 2: 5491, 3: 8657, 4: 3690},
#  'vet_id': {0: 5447, 1: 3441, 2: 3441, 3: 5447, 4: 2296},
#  'waiting_room_shift_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan}}

# %% [markdown]
# ***eliminar dx, waiting_room_shift_id y deleted_at. Evaluar si vale la pena imputar o conservar parcialmente discharge_date y details***

# %% [markdown]
# #### Imagenologia.xlsx

# %%
##Forma
print("Forma (size) del DataFrame:")
pprint(resultados_analisis["imagenologia.xlsx"]["Sheet1"]["forma"])
##Tipos de datos
print("Tipos de datos:")
pprint(resultados_analisis["imagenologia.xlsx"]["Sheet1"]["tipos_datos"])
##Columnas
print("Columnas:")
pprint(resultados_analisis["imagenologia.xlsx"]["Sheet1"]["columnas"])
##Valores nulos
print("Valores nulos:")
pprint(resultados_analisis["imagenologia.xlsx"]["Sheet1"]["valores_nulos"])
##Estadisticas de tendencia central
print("Estadísticas de tendencia central:")
pprint(resultados_analisis["imagenologia.xlsx"]["Sheet1"]["estadisticas_tendencia_central"])
##Muestra de los primeros 5 registros
print("Ejemplo de los primeros 5 registros:")
pprint(resultados_analisis["imagenologia.xlsx"]["Sheet1"]["ejemplo"])
# Out:
# Forma (size) del DataFrame:
# (1000, 18)
# Tipos de datos:
# {'clinical_signs': 'object',
#  'created_at': 'object',
#  'date': 'object',
#  'deleted_at': 'object',
#  'details': 'object',
#  'dx': 'object',
#  'files': 'object',
#  'id': 'int64',
#  'image_type': 'object',
#  'order_item_id': 'float64',
#  'pet_id': 'int64',
#  'presumptive_diagnosis': 'object',
#  'study_type': 'object',
#  'type_other': 'object',
#  'updated_at': 'object',
#  'user_id': 'int64',
#  'vet_id': 'int64',
#  'waiting_room_shift_id': 'float64'}
# Columnas:
# ['id',
#  'pet_id',
#  'vet_id',
#  'user_id',
#  'order_item_id',
#  'date',
#  'clinical_signs',
#  'presumptive_diagnosis',
#  'study_type',
#  'image_type',
#  'type_other',
#  'details',
#  'files',
#  'dx',
#  'waiting_room_shift_id',
#  'created_at',
#  'updated_at',
#  'deleted_at']
# Valores nulos:
# {'clinical_signs': 29,
#  'created_at': 0,
#  'date': 0,
#  'deleted_at': 987,
#  'details': 556,
#  'dx': 996,
#  'files': 134,
#  'id': 0,
#  'image_type': 0,
#  'order_item_id': 971,
#  'pet_id': 0,
#  'presumptive_diagnosis': 2,
#  'study_type': 132,
#  'type_other': 981,
#  'updated_at': 0,
#  'user_id': 0,
#  'vet_id': 0,
#  'waiting_room_shift_id': 999}
# Estadísticas de tendencia central:
# {'id': {'media': 157091.5, 'mediana': 157091.5, 'nulos': 0},
#  'order_item_id': {'media': 106326.79310344828,
#                    'mediana': 106350.0,
#                    'nulos': 971},
#  'pet_id': {'media': 1506973.265, 'mediana': 1891492.5, 'nulos': 0},
#  'user_id': {'media': 12482.405, 'mediana': 13814.0, 'nulos': 0},
#  'vet_id': {'media': 5878.089, 'mediana': 4983.0, 'nulos': 0},
#  'waiting_room_shift_id': {'media': 22942.0, 'mediana': 22942.0, 'nulos': 999}}
# Ejemplo de los primeros 5 registros:
# {'clinical_signs': {0: '1. Cojera leve e intermitente\n'
#                        '2. Paraparesia temporal, reportada por tutora',
#                     1: '.',
#                     2: 'Claudicación 3/4 MAD',
#                     3: 'La adoptaron hace un mes.',
#                     4: '.'},
#  'created_at': {0: '2025-05-28 12:59:27',
#                 1: '2025-05-28 12:53:36',
#                 2: '2025-05-28 12:47:21',
#                 3: '2025-05-28 12:45:00',
#                 4: '2025-05-28 12:44:06'},
#  'date': {0: '2025-05-28',
#           1: '2025-05-28',
#           2: '2025-05-28',
#           3: '2025-05-28',
#           4: '2025-05-28'},
#  'deleted_at': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'details': {0: 'Se evidencian espóndilos en las caras ventrales de los '
#                 'cuerpos vertebrales entre las vértebras T11 y T12, T12 y '
#                 'T13.\n'
#                 'No se evidencian cambios en espacios intervertebrales. Se '
#                 'observa posible pinzamiento medular entre T12 y T13.',
#              1: nan,
#              2: nan,
#              3: nan,
#              4: nan},
#  'dx': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'files': {0: '[{"name": "ROCCO CONGOTE.docx.pdf", "path": '
#               '"VetFiles/7034/Imaging/hB6d6JaDjoNBU7zxyiaE3g7PjOOT6bz8tOkQuwYk.pdf"}, '
#               '{"name": "DX000085_1.jpg", "path": '
#               '"VetFiles/7034/Imaging/cFcg15MFNTkxFqtpSgRnYw2N8WnfrL5VZ3SvzBKi.jpg"}, '
#               '{"name": "DX000085_2.jpg", "path": '
#               '"VetFiles/7034/Imaging/JLd3rhtHpAber9nL6II5P4B7yxSqCbaiSJjLCSYY.jpg"}, '
#               '{"name": "DX000085_3.jpg", "path": '
#               '"VetFiles/7034/Imaging/34P3DsZjYoYpEHipExiAKFCr5XvNTipIAVo6RLhx.jpg"}, '
#               '{"name": "DX000085_4.jpg", "path": '
#               '"VetFiles/7034/Imaging/RBqjPbrLd4tJGOQx4i49OwzKGia25wATEjAdjCBG.jpg"}]',
#            1: '[{"name": "Jerry Castaño - Encéfalo.pdf", "path": '
#               '"VetFiles/23/Imaging/uZjtNeq6b6I3yiBIEi9DaiAU7zvOAa7Idy9DkSVm.pdf"}]',
#            2: nan,
#            3: nan,
#            4: '[{"name": "Lupita Mazo - Columna C.pdf", "path": '
#               '"VetFiles/23/Imaging/jR0oeldseFNZwrglfDRqCYJOymTlT9FIR6bD4coi.pdf"}]'},
#  'id': {0: 157591, 1: 157590, 2: 157589, 3: 157588, 4: 157587},
#  'image_type': {0: 'bonescan',
#                 1: 'mri',
#                 2: 'bonescan',
#                 3: 'ultrasound',
#                 4: 'mri'},
#  'order_item_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'pet_id': {0: 1383138, 1: 32595, 2: 1952005, 3: 1952005, 4: 1115145},
#  'presumptive_diagnosis': {0: 'ESPONDOSIS TORACOLUMBAR (ENTRE T11 Y T13)',
#                            1: '.',
#                            2: 'Luxación de codo derecho.',
#                            3: 'Chequeo general. (evaluar si esta esterilizada)',
#                            4: '.'},
#  'study_type': {0: 'Radiografías L-L izquierda y V-D de columna',
#                 1: 'Resonancia magnética',
#                 2: 'Rx LL y AP de MAD.',
#                 3: 'Ecografia abdominal',
#                 4: 'Resonancia magnética'},
#  'type_other': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'updated_at': {0: '2025-05-28 12:59:27',
#                 1: '2025-05-28 12:53:36',
#                 2: '2025-05-28 12:47:21',
#                 3: '2025-05-28 12:45:00',
#                 4: '2025-05-28 12:44:06'},
#  'user_id': {0: 11131, 1: 331, 2: 34, 3: 34, 4: 331},
#  'vet_id': {0: 7034, 1: 23, 2: 23, 3: 23, 4: 23},
#  'waiting_room_shift_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan}}

# %% [markdown]
# Eliminar columnas:
#
# - dx: 996 nulos, sin utilidad para el análisis inmediato.
#
# - type_other: 981 nulos, muy poco aporte.
#
# - order_item_id: 971 nulos, parece ser un campo auxiliar sin continuidad.
#
# - waiting_room_shift_id: 999 nulos.
#
# - deleted_at: 987 nulos, sin utilidad activa.

# %% [markdown]
#  Imputar o clasificar:
#
# - details: 556 nulos → imputar con "No reportado".
#
# - files: 134 nulos → imputar con lista vacía o string "Sin archivo".
#
# - clinical_signs: 29 nulos → imputar con "Sin signos clínicos".
#
# - presumptive_diagnosis: 2 nulos → imputar con "Sin diagnóstico presuntivo".
#
# - study_type: 132 nulos → evaluar con image_type si se puede inferir.
#
#
# Conversión de tipos:
# - Convertir date, created_at, updated_at a tipo datetime.
#
# - Si se desea estandarizar, desanidar files en una tabla aparte.

# %% [markdown]
# #### ordenes_cabecera.xlsx

# %%
##Forma
print("Forma (size) del DataFrame:")
pprint(resultados_analisis["ordenes_cabecera.xlsx"]["Sheet1"]["forma"])
##Tipos de datos
print("Tipos de datos:")
pprint(resultados_analisis["ordenes_cabecera.xlsx"]["Sheet1"]["tipos_datos"])
##Columnas
print("Columnas:")
pprint(resultados_analisis["ordenes_cabecera.xlsx"]["Sheet1"]["columnas"])
##Valores nulos
print("Valores nulos:")
pprint(resultados_analisis["ordenes_cabecera.xlsx"]["Sheet1"]["valores_nulos"])
##Estadisticas de tendencia central
print("Estadísticas de tendencia central:")
pprint(resultados_analisis["ordenes_cabecera.xlsx"]["Sheet1"]["estadisticas_tendencia_central"])
##Muestra de los primeros 5 registros
print("Ejemplo de los primeros 5 registros:")
pprint(resultados_analisis["ordenes_cabecera.xlsx"]["Sheet1"]["ejemplo"])
# Out:
# Forma (size) del DataFrame:
# (1000, 10)
# Tipos de datos:
# {'created_at': 'object',
#  'deleted_at': 'object',
#  'id': 'int64',
#  'observation': 'object',
#  'order_date': 'object',
#  'pet_id': 'int64',
#  'updated_at': 'object',
#  'user_id': 'int64',
#  'vet_id': 'int64',
#  'waiting_room_shift_id': 'float64'}
# Columnas:
# ['id',
#  'pet_id',
#  'user_id',
#  'vet_id',
#  'order_date',
#  'observation',
#  'waiting_room_shift_id',
#  'created_at',
#  'updated_at',
#  'deleted_at']
# Valores nulos:
# {'created_at': 0,
#  'deleted_at': 990,
#  'id': 0,
#  'observation': 0,
#  'order_date': 0,
#  'pet_id': 0,
#  'updated_at': 0,
#  'user_id': 0,
#  'vet_id': 0,
#  'waiting_room_shift_id': 972}
# Estadísticas de tendencia central:
# {'id': {'media': 79927.5, 'mediana': 79927.5, 'nulos': 0},
#  'pet_id': {'media': 1480602.259, 'mediana': 1719919.0, 'nulos': 0},
#  'user_id': {'media': 13523.227, 'mediana': 16171.5, 'nulos': 0},
#  'vet_id': {'media': 7718.78, 'mediana': 10287.0, 'nulos': 0},
#  'waiting_room_shift_id': {'media': 22837.89285714286,
#                            'mediana': 22870.5,
#                            'nulos': 972}}
# Ejemplo de los primeros 5 registros:
# {'created_at': {0: '2025-05-28 13:50:24',
#                 1: '2025-05-28 13:47:02',
#                 2: '2025-05-28 13:45:57',
#                 3: '2025-05-28 12:45:38',
#                 4: '2025-05-28 12:28:15'},
#  'deleted_at': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'id': {0: 80427, 1: 80426, 2: 80425, 3: 80424, 4: 80423},
#  'observation': {0: 'leve dolor en metatarso en 1 falange',
#                  1: 'posibles  prequirurgicos',
#                  2: '.',
#                  3: 'Post quirúrgico excisión de cabeza y cuello femoral MPD',
#                  4: 'DECAIDA'},
#  'order_date': {0: '2025-05-27',
#                 1: '2025-05-27',
#                 2: '2025-05-27',
#                 3: '2025-05-28',
#                 4: '2025-05-28'},
#  'pet_id': {0: 1977944, 1: 1976650, 2: 1976650, 3: 1949535, 4: 1632634},
#  'updated_at': {0: '2025-05-28 13:50:24',
#                 1: '2025-05-28 13:47:02',
#                 2: '2025-05-28 13:46:07',
#                 3: '2025-05-28 12:45:38',
#                 4: '2025-05-28 12:28:15'},
#  'user_id': {0: 22274, 1: 22274, 2: 22274, 3: 20176, 4: 20221},
#  'vet_id': {0: 15053, 1: 15053, 2: 15053, 3: 28, 4: 13444},
#  'waiting_room_shift_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan}}

# %% [markdown]
# 🔹 Eliminar columnas:
#
# - deleted_at: 1000 nulos, sin utilidad.
#
# - waiting_room_shift_id: 998 nulos, campo prescindible en esta hoja.
#
# 🔹 Imputar o clasificar:
#
# - observation: 409 nulos → imputar con "Sin observación".
#
# 🔹 Conversión de tipos:
#
# - Convertir order_date, created_at, updated_at a datetime.

# %% [markdown]
# #### ordenes_items.xlsx

# %%
##Forma
print("Forma (size) del DataFrame:")
pprint(resultados_analisis["ordenes_items.xlsx"]["Sheet1"]["forma"])
##Tipos de datos
print("Tipos de datos:")
pprint(resultados_analisis["ordenes_items.xlsx"]["Sheet1"]["tipos_datos"])
##Columnas
print("Columnas:")
pprint(resultados_analisis["ordenes_items.xlsx"]["Sheet1"]["columnas"])
##Valores nulos
print("Valores nulos:")
pprint(resultados_analisis["ordenes_items.xlsx"]["Sheet1"]["valores_nulos"])
##Estadisticas de tendencia central
print("Estadísticas de tendencia central:")
pprint(resultados_analisis["ordenes_items.xlsx"]["Sheet1"]["estadisticas_tendencia_central"])
##Muestra de los primeros 5 registros
print("Ejemplo de los primeros 5 registros:")
pprint(resultados_analisis["ordenes_items.xlsx"]["Sheet1"]["ejemplo"])
# Out:
# Forma (size) del DataFrame:
# (1000, 13)
# Tipos de datos:
# {'commandable_id': 'float64',
#  'commandable_type': 'object',
#  'created_at': 'object',
#  'deleted_at': 'float64',
#  'id': 'int64',
#  'level': 'object',
#  'notes': 'object',
#  'order_id': 'int64',
#  'pending': 'float64',
#  'quantity': 'int64',
#  'type_other': 'object',
#  'updated_at': 'object',
#  'user_id': 'float64'}
# Columnas:
# ['id',
#  'order_id',
#  'commandable_type',
#  'commandable_id',
#  'type_other',
#  'quantity',
#  'level',
#  'notes',
#  'pending',
#  'user_id',
#  'created_at',
#  'updated_at',
#  'deleted_at']
# Valores nulos:
# {'commandable_id': 7,
#  'commandable_type': 0,
#  'created_at': 0,
#  'deleted_at': 1000,
#  'id': 0,
#  'level': 393,
#  'notes': 554,
#  'order_id': 0,
#  'pending': 576,
#  'quantity': 0,
#  'type_other': 993,
#  'updated_at': 0,
#  'user_id': 783}
# Estadísticas de tendencia central:
# {'commandable_id': {'media': 1206341.081570997, 'mediana': 48772.0, 'nulos': 7},
#  'deleted_at': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'id': {'media': 106688.5, 'mediana': 106688.5, 'nulos': 0},
#  'order_id': {'media': 80043.949, 'mediana': 80050.0, 'nulos': 0},
#  'pending': {'media': 0.4882075471698113, 'mediana': 0.0, 'nulos': 576},
#  'quantity': {'media': 1.041, 'mediana': 1.0, 'nulos': 0},
#  'user_id': {'media': 17988.437788018433, 'mediana': 20238.0, 'nulos': 783}}
# Ejemplo de los primeros 5 registros:
# {'commandable_id': {0: 2.0, 1: 3422836.0, 2: 1.0, 3: 1.0, 4: 2.0},
#  'commandable_type': {0: 'App\\Models\\ImageType',
#                       1: 'App\\Models\\LaboratoryTest',
#                       2: 'App\\Models\\ImageType',
#                       3: 'App\\Models\\ImageType',
#                       4: 'App\\Models\\ImageType'},
#  'created_at': {0: '2025-05-28 13:50:24',
#                 1: '2025-05-28 13:47:02',
#                 2: '2025-05-28 13:45:57',
#                 3: '2025-05-28 12:45:38',
#                 4: '2025-05-28 12:45:38'},
#  'deleted_at': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'id': {0: 107188, 1: 107187, 2: 107186, 3: 107185, 4: 107184},
#  'level': {0: 'optional',
#            1: 'urgent',
#            2: 'urgent',
#            3: 'priority',
#            4: 'priority'},
#  'notes': {0: '.',
#            1: 'dx en otra clinica',
#            2: 'con dx de otra clinica',
#            3: 'Abdominal en ayuno (Inapetencia, anemia moderada)',
#            4: 'Cadera Control'},
#  'order_id': {0: 80427, 1: 80426, 2: 80425, 3: 80424, 4: 80424},
#  'pending': {0: nan, 1: nan, 2: nan, 3: 1.0, 4: 1.0},
#  'quantity': {0: 1, 1: 1, 2: 1, 3: 1, 4: 1},
#  'type_other': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'updated_at': {0: '2025-05-28 13:50:24',
#                 1: '2025-05-28 13:47:02',
#                 2: '2025-05-28 13:45:57',
#                 3: '2025-05-28 12:45:38',
#                 4: '2025-05-28 12:45:38'},
#  'user_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan}}

# %% [markdown]
# 🔹 Eliminar columnas:
#
# - deleted_at: 1000 nulos.
#
# - type_other: 993 nulos.
#
# - user_id: 783 nulos → revisar si se puede asociar con cabecera, si no, eliminar.
#
# 🔹 Imputar o clasificar:
#
# - pending: 576 nulos → clasificar como 0 (no pendiente) si se justifica.
#
# - notes: 554 nulos → imputar con "Sin notas".
#
# - level: 393 nulos → imputar con "Sin prioridad".
#
# - commandable_id: 7 nulos → posible imputación si commandable_type lo permite.
#
# 🔹 Conversión de tipos:
#
# - Convertir created_at, updated_at a datetime.

# %% [markdown]
# #### peluqueria_spa_cabecera.xlsx

# %%
##Forma
print("Forma (size) del DataFrame:")
pprint(resultados_analisis["peluqueria_spa_cabecera.xlsx"]["Sheet1"]["forma"])
##Tipos de datos
print("Tipos de datos:")
pprint(resultados_analisis["peluqueria_spa_cabecera.xlsx"]["Sheet1"]["tipos_datos"])
##Columnas
print("Columnas:")
pprint(resultados_analisis["peluqueria_spa_cabecera.xlsx"]["Sheet1"]["columnas"])
##Valores nulos
print("Valores nulos:")
pprint(resultados_analisis["peluqueria_spa_cabecera.xlsx"]["Sheet1"]["valores_nulos"])
##Estadisticas de tendencia central
print("Estadísticas de tendencia central:")
pprint(resultados_analisis["peluqueria_spa_cabecera.xlsx"]["Sheet1"]["estadisticas_tendencia_central"])
##Muestra de los primeros 5 registros
print("Ejemplo de los primeros 5 registros:")
pprint(resultados_analisis["peluqueria_spa_cabecera.xlsx"]["Sheet1"]["ejemplo"])
# Out:
# Forma (size) del DataFrame:
# (1000, 14)
# Tipos de datos:
# {'created_at': 'object',
#  'date': 'object',
#  'deleted_at': 'object',
#  'details': 'object',
#  'file_after': 'object',
#  'file_before': 'object',
#  'id': 'int64',
#  'next_control_at': 'object',
#  'pet_id': 'int64',
#  'rabies_vaccine': 'object',
#  'updated_at': 'object',
#  'user_id': 'int64',
#  'vet_id': 'int64',
#  'waiting_room_shift_id': 'float64'}
# Columnas:
# ['id',
#  'pet_id',
#  'vet_id',
#  'user_id',
#  'date',
#  'details',
#  'rabies_vaccine',
#  'file_before',
#  'file_after',
#  'next_control_at',
#  'waiting_room_shift_id',
#  'created_at',
#  'updated_at',
#  'deleted_at']
# Valores nulos:
# {'created_at': 0,
#  'date': 0,
#  'deleted_at': 995,
#  'details': 656,
#  'file_after': 972,
#  'file_before': 957,
#  'id': 0,
#  'next_control_at': 703,
#  'pet_id': 0,
#  'rabies_vaccine': 873,
#  'updated_at': 0,
#  'user_id': 0,
#  'vet_id': 0,
#  'waiting_room_shift_id': 1000}
# Estadísticas de tendencia central:
# {'id': {'media': 259912.5, 'mediana': 259912.5, 'nulos': 0},
#  'pet_id': {'media': 1393978.999, 'mediana': 1515376.0, 'nulos': 0},
#  'user_id': {'media': 12237.03, 'mediana': 11182.0, 'nulos': 0},
#  'vet_id': {'media': 6225.766, 'mediana': 5263.0, 'nulos': 0},
#  'waiting_room_shift_id': {'media': nan, 'mediana': nan, 'nulos': 1000}}
# Ejemplo de los primeros 5 registros:
# {'created_at': {0: '2025-05-28 15:01:14',
#                 1: '2025-05-28 13:00:22',
#                 2: '2025-05-28 12:00:11',
#                 3: '2025-05-28 11:59:25',
#                 4: '2025-05-28 11:57:01'},
#  'date': {0: '2025-02-07 15:01:00',
#           1: '2025-05-28 12:59:00',
#           2: '2025-05-28 11:59:00',
#           3: '2025-05-28 11:59:00',
#           4: '2025-05-28 11:56:00'},
#  'deleted_at': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'details': {0: nan, 1: 'Dermatitis', 2: nan, 3: nan, 4: nan},
#  'file_after': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'file_before': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'id': {0: 260412, 1: 260411, 2: 260410, 3: 260409, 4: 260408},
#  'next_control_at': {0: nan,
#                      1: '2025-06-28',
#                      2: '2025-06-28',
#                      3: '2025-06-28',
#                      4: '2025-06-28'},
#  'pet_id': {0: 235240, 1: 1978078, 2: 1030626, 3: 1054704, 4: 1054713},
#  'rabies_vaccine': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'updated_at': {0: '2025-05-28 15:01:14',
#                 1: '2025-05-28 13:00:22',
#                 2: '2025-05-28 12:00:11',
#                 3: '2025-05-28 11:59:25',
#                 4: '2025-05-28 11:57:01'},
#  'user_id': {0: 4839, 1: 24049, 2: 13719, 3: 13719, 4: 13719},
#  'vet_id': {0: 3047, 1: 16372, 2: 8614, 3: 8614, 4: 8614},
#  'waiting_room_shift_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan}}

# %% [markdown]
# Eliminar columnas:
#
# - deleted_at: 1000 nulos.
#
# - waiting_room_shift_id: 1000 nulos, sin relevancia.
#
# 🔹 Imputar o clasificar:
#
# - file_before, file_after: 565 y 639 nulos respectivamente → imputar con "Sin archivo".
#
# - details: 400 nulos → imputar con "No especificado".
#
# - rabies_vaccine: 212 nulos → imputar con "No registrada".
#
# - next_control_at: 537 nulos → puede clasificarse como "Sin programación".
#
# 🔹 Conversión de tipos:
#
# - Convertir date, next_control_at, created_at, updated_at a datetime.

# %% [markdown]
# #### peluqueria_spa_items

# %%
##Forma
print("Forma (size) del DataFrame:")
pprint(resultados_analisis["peluqueria_spa_items.xlsx"]["Sheet1"]["forma"])
##Tipos de datos
print("Tipos de datos:")
pprint(resultados_analisis["peluqueria_spa_items.xlsx"]["Sheet1"]["tipos_datos"])
##Columnas
print("Columnas:")
pprint(resultados_analisis["peluqueria_spa_items.xlsx"]["Sheet1"]["columnas"])
##Valores nulos
print("Valores nulos:")
pprint(resultados_analisis["peluqueria_spa_items.xlsx"]["Sheet1"]["valores_nulos"])
##Estadisticas de tendencia central
print("Estadísticas de tendencia central:")
pprint(resultados_analisis["peluqueria_spa_items.xlsx"]["Sheet1"]["estadisticas_tendencia_central"])
##Muestra de los primeros 5 registros
print("Ejemplo de los primeros 5 registros:")
pprint(resultados_analisis["peluqueria_spa_items.xlsx"]["Sheet1"]["ejemplo"])
# Out:
# Forma (size) del DataFrame:
# (1000, 8)
# Tipos de datos:
# {'created_at': 'object',
#  'deleted_at': 'float64',
#  'details': 'object',
#  'id': 'int64',
#  'responsible_id': 'float64',
#  'spa_id': 'int64',
#  'subject': 'object',
#  'updated_at': 'object'}
# Columnas:
# ['id',
#  'spa_id',
#  'subject',
#  'responsible_id',
#  'details',
#  'created_at',
#  'updated_at',
#  'deleted_at']
# Valores nulos:
# {'created_at': 0,
#  'deleted_at': 1000,
#  'details': 644,
#  'id': 0,
#  'responsible_id': 562,
#  'spa_id': 0,
#  'subject': 0,
#  'updated_at': 0}
# Estadísticas de tendencia central:
# {'deleted_at': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'id': {'media': 266134.5, 'mediana': 266134.5, 'nulos': 0},
#  'responsible_id': {'media': 13323.648401826484,
#                     'mediana': 12781.0,
#                     'nulos': 562},
#  'spa_id': {'media': 259918.409, 'mediana': 259919.5, 'nulos': 0}}
# Ejemplo de los primeros 5 registros:
# {'created_at': {0: '2025-05-28 15:01:52',
#                 1: '2025-05-28 15:01:14',
#                 2: '2025-05-28 13:00:22',
#                 3: '2025-05-28 12:00:11',
#                 4: '2025-05-28 11:59:25'},
#  'deleted_at': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'details': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'id': {0: 266634, 1: 266633, 2: 266632, 3: 266631, 4: 266630},
#  'responsible_id': {0: 4839.0, 1: 4839.0, 2: 24049.0, 3: nan, 4: nan},
#  'spa_id': {0: 260413, 1: 260412, 2: 260411, 3: 260410, 4: 260409},
#  'subject': {0: 'BAÑO MEDICADO',
#              1: 'BAÑO MEDICADO',
#              2: 'baño y peluqueria',
#              3: 'BAÑO Y CEPILLADO',
#              4: 'BAÑO Y CEPILLADO'},
#  'updated_at': {0: '2025-05-28 15:01:52',
#                 1: '2025-05-28 15:01:14',
#                 2: '2025-05-28 13:00:22',
#                 3: '2025-05-28 12:00:11',
#                 4: '2025-05-28 11:59:25'}}

# %% [markdown]
# 🔹 Eliminar columnas:
#
# - deleted_at: 1000 nulos.
#
# 🔹 Imputar o clasificar:
#
# - details: 644 nulos → imputar con "Sin detalles".
#
# - responsible_id: 992 nulos → si no es vital, eliminar o marcar como "Sin responsable".
#
# 🔹 Conversión de tipos:
#
# - created_at, updated_at → convertir a datetime.

# %% [markdown]
# #### remisiones.xlsx

# %%
##Forma
print("Forma (size) del DataFrame:")
pprint(resultados_analisis["remisiones.xlsx"]["Sheet1"]["forma"])
##Tipos de datos
print("Tipos de datos:")
pprint(resultados_analisis["remisiones.xlsx"]["Sheet1"]["tipos_datos"])
##Columnas
print("Columnas:")
pprint(resultados_analisis["remisiones.xlsx"]["Sheet1"]["columnas"])
##Valores nulos
print("Valores nulos:")
pprint(resultados_analisis["remisiones.xlsx"]["Sheet1"]["valores_nulos"])
##Estadisticas de tendencia central
print("Estadísticas de tendencia central:")
pprint(resultados_analisis["remisiones.xlsx"]["Sheet1"]["estadisticas_tendencia_central"])
##Muestra de los primeros 5 registros
print("Ejemplo de los primeros 5 registros:")
pprint(resultados_analisis["remisiones.xlsx"]["Sheet1"]["ejemplo"])
# Out:
# Forma (size) del DataFrame:
# (1000, 14)
# Tipos de datos:
# {'created_at': 'object',
#  'deleted_at': 'object',
#  'destination': 'object',
#  'dx': 'float64',
#  'id': 'int64',
#  'observations': 'object',
#  'pet_id': 'int64',
#  'profesional_id': 'int64',
#  'reason': 'object',
#  'referral_at': 'object',
#  'updated_at': 'object',
#  'user_id': 'int64',
#  'vet_id': 'int64',
#  'waiting_room_shift_id': 'float64'}
# Columnas:
# ['id',
#  'pet_id',
#  'vet_id',
#  'user_id',
#  'profesional_id',
#  'referral_at',
#  'destination',
#  'reason',
#  'observations',
#  'dx',
#  'waiting_room_shift_id',
#  'created_at',
#  'updated_at',
#  'deleted_at']
# Valores nulos:
# {'created_at': 0,
#  'deleted_at': 983,
#  'destination': 4,
#  'dx': 1000,
#  'id': 0,
#  'observations': 149,
#  'pet_id': 0,
#  'profesional_id': 0,
#  'reason': 0,
#  'referral_at': 0,
#  'updated_at': 0,
#  'user_id': 0,
#  'vet_id': 0,
#  'waiting_room_shift_id': 998}
# Estadísticas de tendencia central:
# {'dx': {'media': nan, 'mediana': nan, 'nulos': 1000},
#  'id': {'media': 59507.5, 'mediana': 59507.5, 'nulos': 0},
#  'pet_id': {'media': 1611082.049, 'mediana': 1932825.0, 'nulos': 0},
#  'profesional_id': {'media': 11490.12, 'mediana': 11790.0, 'nulos': 0},
#  'user_id': {'media': 11441.525, 'mediana': 11790.0, 'nulos': 0},
#  'vet_id': {'media': 6013.449, 'mediana': 5015.0, 'nulos': 0},
#  'waiting_room_shift_id': {'media': 22435.0, 'mediana': 22435.0, 'nulos': 998}}
# Ejemplo de los primeros 5 registros:
# {'created_at': {0: '2025-05-28 13:01:50',
#                 1: '2025-05-28 12:44:46',
#                 2: '2025-05-28 12:33:58',
#                 3: '2025-05-28 12:12:43',
#                 4: '2025-05-28 12:11:19'},
#  'deleted_at': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'destination': {0: 'VETERINARIA LA ESTRELLA',
#                  1: 'pets',
#                  2: 'CLINICA VETERINARIA',
#                  3: 'ANIMAL VETER',
#                  4: 'Clinica Veterinaria San Rafael'},
#  'dx': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'id': {0: 60007, 1: 60006, 2: 60005, 3: 60004, 4: 60003},
#  'observations': {0: 'La Estrella Clínica Veterinaria\n'
#                      'Dirección: Barrio la estrella, Cra. 24b #61 A - 37, '
#                      'Manizales, Caldas\n'
#                      'Teléfono: 315 2308233',
#                   1: 'Se envía reporte ecográfico a la tutora, en el que se '
#                      'evidencia abundante contenido en colon sugerente de '
#                      'constipación/estreñimiento.',
#                   2: '------------',
#                   3: 'Se envian muestras de sangre para prequirurgicos e '
#                      'imagenes ecograficas a centro medico receptor.',
#                   4: '- paciente con neoproliferación mamaria caudal \n'
#                      '- cita con el Dr Rafael Velosa'},
#  'pet_id': {0: 1746143, 1: 1288443, 2: 1973467, 3: 1978003, 4: 1896381},
#  'profesional_id': {0: 16846, 1: 2821, 2: 644, 3: 17005, 4: 4260},
#  'reason': {0: 'PACIENTE REMITIDA A CONSULTA ESPECIALIZADA POR DERMATOLOGIA',
#             1: 'Se remite paciente para manejo intrahospitalario y radiografía '
#                'de abdomen. \n'
#                '\n'
#                'Dx. DEFINITIVO: \n'
#                'Fecaloma\n'
#                '\n'
#                'La paciente se encuentra clínicamente estable, sin embargo, '
#                'presenta emesis (2 episodios dia aprox), ptialismo, abdomen '
#                'distendido, tenesmo fecal, dolor moderado a severo palpación '
#                'abdominal caudal derecha y presencia de materia fecal seca a '
#                'la palpación rectal.',
#             2: 'ECOGRAFIA ABDOMINAL / CISTITIS IDIOPATICA - UROLITIASIS '
#                '-------',
#             3: 'Se remite paciente para endoscopia por cuerpo extraño a nivel '
#                'gastrico.',
#             4: '- se remite paciente para evaluación y programación de proceso '
#                'quirúrgico por neoplasia en glándula mamaria caudal'},
#  'referral_at': {0: '2025-05-28 13:00:00',
#                  1: '2025-05-28 12:28:00',
#                  2: '2025-05-28 12:30:00',
#                  3: '2025-05-28 12:10:00',
#                  4: '2025-05-28 12:07:00'},
#  'updated_at': {0: '2025-05-28 13:01:50',
#                 1: '2025-05-28 12:44:46',
#                 2: '2025-05-28 12:33:58',
#                 3: '2025-05-28 12:12:43',
#                 4: '2025-05-28 12:11:19'},
#  'user_id': {0: 2167, 1: 2821, 2: 24896, 3: 17005, 4: 4260},
#  'vet_id': {0: 3665, 1: 3030, 2: 16963, 3: 11253, 4: 2680},
#  'waiting_room_shift_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan}}

# %% [markdown]
# 🔹 Eliminar columnas:
#
# - deleted_at: 999 nulos, sin utilidad.
#
# - waiting_room_shift_id: 998 nulos, prescindible.
#
# 🔹 Imputar o clasificar:
#
# - reason: 234 nulos → imputar con "No especificado".
#
# - details: 877 nulos → imputar con "Sin detalles".
#
# - file: 986 nulos → imputar con "Sin archivo".
#
# - vet_referred_to: 202 nulos → imputar con "No informado".
#
# - file_description: 984 nulos → imputar con "Sin descripción".
#
# - reception_observation: 984 nulos → imputar con "Sin observación".
#
# 🔹 Conversión de tipos:
#
# - Convertir date, created_at, updated_at a datetime.

# %% [markdown]
# #### seguimientos.xlsx

# %%
print("Forma (size) del DataFrame:")
pprint(resultados_analisis["seguimientos.xlsx"]["Sheet1"]["forma"])
##Tipos de datos
print("Tipos de datos:")
pprint(resultados_analisis["seguimientos.xlsx"]["Sheet1"]["tipos_datos"])
##Columnas
print("Columnas:")
pprint(resultados_analisis["seguimientos.xlsx"]["Sheet1"]["columnas"])
##Valores nulos
print("Valores nulos:")
pprint(resultados_analisis["seguimientos.xlsx"]["Sheet1"]["valores_nulos"])
##Estadisticas de tendencia central
print("Estadísticas de tendencia central:")
pprint(resultados_analisis["seguimientos.xlsx"]["Sheet1"]["estadisticas_tendencia_central"])
##Muestra de los primeros 5 registros
print("Ejemplo de los primeros 5 registros:")
pprint(resultados_analisis["seguimientos.xlsx"]["Sheet1"]["ejemplo"])
# Out:
# Forma (size) del DataFrame:
# (1000, 32)
# Tipos de datos:
# {'bcs': 'object',
#  'blood_pressure': 'object',
#  'breathing_rate': 'object',
#  'created_at': 'object',
#  'crt': 'object',
#  'deleted_at': 'object',
#  'details': 'object',
#  'dx': 'object',
#  'file': 'object',
#  'glycemia': 'object',
#  'heart_rate': 'object',
#  'heartbeat': 'object',
#  'id': 'int64',
#  'monitorable_id': 'float64',
#  'monitorable_type': 'object',
#  'monitoring_at': 'object',
#  'mucous_membrane': 'object',
#  'next_control_at': 'object',
#  'observations': 'object',
#  'palpation': 'object',
#  'pet_id': 'int64',
#  'reflexes': 'object',
#  'saturation': 'object',
#  'temperature': 'float64',
#  'temperature_unit': 'object',
#  'type': 'float64',
#  'updated_at': 'object',
#  'user_id': 'int64',
#  'vet_id': 'int64',
#  'waiting_room_shift_id': 'float64',
#  'weight': 'float64',
#  'weight_unit': 'object'}
# Columnas:
# ['id',
#  'pet_id',
#  'vet_id',
#  'user_id',
#  'monitorable_id',
#  'monitorable_type',
#  'monitoring_at',
#  'type',
#  'details',
#  'next_control_at',
#  'temperature',
#  'temperature_unit',
#  'weight',
#  'weight_unit',
#  'bcs',
#  'crt',
#  'heart_rate',
#  'breathing_rate',
#  'reflexes',
#  'heartbeat',
#  'saturation',
#  'blood_pressure',
#  'mucous_membrane',
#  'glycemia',
#  'palpation',
#  'observations',
#  'file',
#  'dx',
#  'waiting_room_shift_id',
#  'created_at',
#  'updated_at',
#  'deleted_at']
# Valores nulos:
# {'bcs': 890,
#  'blood_pressure': 953,
#  'breathing_rate': 883,
#  'created_at': 0,
#  'crt': 884,
#  'deleted_at': 987,
#  'details': 0,
#  'dx': 997,
#  'file': 846,
#  'glycemia': 977,
#  'heart_rate': 882,
#  'heartbeat': 919,
#  'id': 0,
#  'monitorable_id': 578,
#  'monitorable_type': 578,
#  'monitoring_at': 0,
#  'mucous_membrane': 884,
#  'next_control_at': 962,
#  'observations': 971,
#  'palpation': 957,
#  'pet_id': 0,
#  'reflexes': 928,
#  'saturation': 961,
#  'temperature': 873,
#  'temperature_unit': 873,
#  'type': 478,
#  'updated_at': 0,
#  'user_id': 0,
#  'vet_id': 0,
#  'waiting_room_shift_id': 994,
#  'weight': 884,
#  'weight_unit': 884}
# Estadísticas de tendencia central:
# {'id': {'media': 1370479.5, 'mediana': 1370479.5, 'nulos': 0},
#  'monitorable_id': {'media': 402835.836492891,
#                     'mediana': 222496.5,
#                     'nulos': 578},
#  'pet_id': {'media': 1531716.793, 'mediana': 1885851.5, 'nulos': 0},
#  'temperature': {'media': 38.069055118110235, 'mediana': 38.5, 'nulos': 873},
#  'type': {'media': 3.8544061302681993, 'mediana': 4.0, 'nulos': 478},
#  'user_id': {'media': 13234.539, 'mediana': 14061.0, 'nulos': 0},
#  'vet_id': {'media': 5130.764, 'mediana': 3209.0, 'nulos': 0},
#  'waiting_room_shift_id': {'media': 23047.666666666668,
#                            'mediana': 23048.5,
#                            'nulos': 994},
#  'weight': {'media': 34.38043103448276, 'mediana': 7.8, 'nulos': 884}}
# Ejemplo de los primeros 5 registros:
# {'bcs': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'blood_pressure': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'breathing_rate': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'created_at': {0: '2025-05-28 13:04:05',
#                 1: '2025-05-28 13:03:11',
#                 2: '2025-05-28 13:02:05',
#                 3: '2025-05-28 13:02:01',
#                 4: '2025-05-28 13:01:41'},
#  'crt': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'deleted_at': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'details': {0: 'Paciente ingresa para revisión, reportan  que la ven mejor, '
#                 'con las patitas, esta mejor, pero cundo para e tratamiento, '
#                 'se vuelve a rascar  y esta defecando como con un moco y ayer '
#                 'vomito. \n'
#                 '\n'
#                 '_El ultimo baño fue el lunes. \n'
#                 '\n'
#                 'Peso: 14.8kg \n'
#                 '\n'
#                 'DAC/',
#              1: 'Paciente no asiste a revision',
#              2: 'Enteritis',
#              3: 'S. ELLA VENIA BIEN PERO OTRA VEZ ESTA MOQUIANDO, ELLA HACE '
#                 'COMO PARA SACAR ALGO. \n'
#                 'O. PACIENTE ALERTA, DINAMICA, MUCOSAS ROSADAS Y HUMEDAS, '
#                 'REFLEJO TUSIGENO POSITIVO Y PALMOPERCUTOR NEGATIVO \n'
#                 'SIN SONIDOS CONGESTIVOS A LA AUSCULTACION DEL TORAX. \n'
#                 'I. TRAQUEITIS, CALCIFICACION TRAQUEAL/ESTENOSIS TRAQUEAL \n'
#                 'P. SE ENVIA TERAPIA COMPLEMENTARIA, SE INDICA TRAER A '
#                 'REVISION EN 5 DIAS, EN CASO DE QUE NO HAYA RESOLUCION DE LOS '
#                 'SINTOMAS SE RECOMIENDA REALIZAR RADIOGRAFIA CERVICOTORACICA.',
#              4: 'SCSXCS'},
#  'dx': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'file': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'glycemia': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'heart_rate': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'heartbeat': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'id': {0: 1370979, 1: 1370978, 2: 1370977, 3: 1370976, 4: 1370975},
#  'monitorable_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'monitorable_type': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'monitoring_at': {0: '2025-05-28 13:01:00',
#                    1: '2025-05-28 13:02:00',
#                    2: '2025-05-28 13:00:00',
#                    3: '2025-05-28 13:00:00',
#                    4: '2025-05-28 13:01:00'},
#  'mucous_membrane': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'next_control_at': {0: nan, 1: nan, 2: nan, 3: '2025-06-02', 4: nan},
#  'observations': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'palpation': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'pet_id': {0: 1629921, 1: 1958289, 2: 234371, 3: 148522, 4: 1964136},
#  'reflexes': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'saturation': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'temperature': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'temperature_unit': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'type': {0: nan, 1: nan, 2: 7.0, 3: nan, 4: nan},
#  'updated_at': {0: '2025-05-28 13:04:05',
#                 1: '2025-05-28 13:03:11',
#                 2: '2025-05-28 13:02:05',
#                 3: '2025-05-28 13:02:01',
#                 4: '2025-05-28 13:01:41'},
#  'user_id': {0: 9642, 1: 2264, 2: 9304, 3: 3603, 4: 21755},
#  'vet_id': {0: 6034, 1: 71, 2: 975, 3: 5251, 4: 8374},
#  'waiting_room_shift_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'weight': {0: nan, 1: nan, 2: 13.4, 3: nan, 4: nan},
#  'weight_unit': {0: nan, 1: nan, 2: 'kg', 3: nan, 4: nan}}

# %% [markdown]
# 🔹 Eliminar columnas:
#
# - deleted_at: 1000 nulos, sin utilidad.
#
# - waiting_room_shift_id: 999 nulos, irrelevante para análisis.
#
# 🔹 Imputar o clasificar:
#
# - details: 414 nulos → imputar con "Sin detalles".
#
# - file: 964 nulos → imputar con "Sin archivo".
#
# 🔹 Conversión de tipos:
#
# - Convertir date, created_at, updated_at a datetime.

# %% [markdown]
# #### vacunaciones.xlsx

# %%
print("Forma (size) del DataFrame:")
pprint(resultados_analisis["vacunaciones.xlsx"]["Sheet1"]["forma"])
##Tipos de datos
print("Tipos de datos:")
pprint(resultados_analisis["vacunaciones.xlsx"]["Sheet1"]["tipos_datos"])
##Columnas
print("Columnas:")
pprint(resultados_analisis["vacunaciones.xlsx"]["Sheet1"]["columnas"])
##Valores nulos
print("Valores nulos:")
pprint(resultados_analisis["vacunaciones.xlsx"]["Sheet1"]["valores_nulos"])
##Estadisticas de tendencia central
print("Estadísticas de tendencia central:")
pprint(resultados_analisis["vacunaciones.xlsx"]["Sheet1"]["estadisticas_tendencia_central"])
##Muestra de los primeros 5 registros
print("Ejemplo de los primeros 5 registros:")
pprint(resultados_analisis["vacunaciones.xlsx"]["Sheet1"]["ejemplo"])
# Out:
# Forma (size) del DataFrame:
# (1000, 14)
# Tipos de datos:
# {'created_at': 'object',
#  'deleted_at': 'object',
#  'details': 'object',
#  'id': 'int64',
#  'laboratory': 'object',
#  'lot': 'object',
#  'next_vaccine_at': 'object',
#  'pet_id': 'int64',
#  'updated_at': 'object',
#  'user_id': 'int64',
#  'vaccine_at': 'object',
#  'vaccine_type_id': 'int64',
#  'vet_id': 'int64',
#  'waiting_room_shift_id': 'float64'}
# Columnas:
# ['id',
#  'pet_id',
#  'vet_id',
#  'user_id',
#  'vaccine_type_id',
#  'laboratory',
#  'lot',
#  'details',
#  'vaccine_at',
#  'next_vaccine_at',
#  'waiting_room_shift_id',
#  'created_at',
#  'updated_at',
#  'deleted_at']
# Valores nulos:
# {'created_at': 0,
#  'deleted_at': 998,
#  'details': 482,
#  'id': 0,
#  'laboratory': 332,
#  'lot': 460,
#  'next_vaccine_at': 151,
#  'pet_id': 0,
#  'updated_at': 0,
#  'user_id': 0,
#  'vaccine_at': 0,
#  'vaccine_type_id': 0,
#  'vet_id': 0,
#  'waiting_room_shift_id': 994}
# Estadísticas de tendencia central:
# {'id': {'media': 934729.5, 'mediana': 934729.5, 'nulos': 0},
#  'pet_id': {'media': 1660088.309, 'mediana': 1921643.0, 'nulos': 0},
#  'user_id': {'media': 11474.209, 'mediana': 9772.0, 'nulos': 0},
#  'vaccine_type_id': {'media': 12703.635, 'mediana': 10995.0, 'nulos': 0},
#  'vet_id': {'media': 6105.128, 'mediana': 4595.0, 'nulos': 0},
#  'waiting_room_shift_id': {'media': 23023.166666666668,
#                            'mediana': 23025.0,
#                            'nulos': 994}}
# Ejemplo de los primeros 5 registros:
# {'created_at': {0: '2025-05-28 12:48:17',
#                 1: '2025-05-28 11:47:57',
#                 2: '2025-05-28 11:47:21',
#                 3: '2025-05-28 12:46:50',
#                 4: '2025-05-28 12:46:28'},
#  'deleted_at': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan},
#  'details': {0: '1 DOSIS',
#              1: nan,
#              2: nan,
#              3: 'Al examen clínico no se evidencia alteración fisiológica ni '
#                 'locomotora.\n'
#                 'Paciente apto para vacunación.\n'
#                 'Se administra 1 ml vía subcutánea sin alteración.\n'
#                 'Peso 22.3 kg',
#              4: '8,20kg'},
#  'id': {0: 935229, 1: 935228, 2: 935227, 3: 935226, 4: 935225},
#  'laboratory': {0: nan, 1: nan, 2: nan, 3: 'Virbac', 4: 'Zoetis'},
#  'lot': {0: nan, 1: nan, 2: nan, 3: '9NRC vence 10/26', 4: '723795B/728060'},
#  'next_vaccine_at': {0: '2025-06-18',
#                      1: '2026-05-13',
#                      2: '2026-05-13',
#                      3: '2026-05-28',
#                      4: '2026-05-28'},
#  'pet_id': {0: 1978114, 1: 1978095, 2: 1978095, 3: 1210669, 4: 1936632},
#  'updated_at': {0: '2025-05-28 12:48:17',
#                 1: '2025-05-28 11:47:57',
#                 2: '2025-05-28 11:47:41',
#                 3: '2025-05-28 12:47:20',
#                 4: '2025-05-28 12:46:42'},
#  'user_id': {0: 8411, 1: 23988, 2: 23988, 3: 4045, 4: 3824},
#  'vaccine_at': {0: '2025-05-28',
#                 1: '2025-05-13',
#                 2: '2025-05-13',
#                 3: '2025-05-28',
#                 4: '2025-05-28'},
#  'vaccine_type_id': {0: 10995, 1: 10, 2: 30471, 3: 3766, 4: 12526},
#  'vet_id': {0: 5263, 1: 16324, 2: 16324, 3: 2131, 4: 2343},
#  'waiting_room_shift_id': {0: nan, 1: nan, 2: nan, 3: nan, 4: nan}}

# %% [markdown]
# 🔹 Eliminar columnas:
#
# - deleted_at: 1000 nulos.
#
# - waiting_room_shift_id: 1000 nulos.
#
# - vaccine_other: 981 nulos → campo auxiliar que puede eliminarse.
#
# 🔹 Imputar o clasificar:
#
# - batch: 964 nulos → imputar con "Desconocido".
#
# - lab: 962 nulos → imputar con "No informado".
#
# - vaccine_type: 35 nulos → imputar con "Tipo no registrado".
#
# - observations: 790 nulos → imputar con "Sin observaciones".
#
# - vaccine_place: 964 nulos → imputar con "No especificado".
#
# - rabies_tag: 964 nulos → imputar con "Sin etiqueta".
#
# - file: 987 nulos → imputar con "Sin archivo".
#
# 🔹 Conversión de tipos:
#
# - Convertir date, next_control_at, created_at, updated_at a datetime.
